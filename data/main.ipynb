# %%
import os
import shutil
from PIL import Image # Para verificar dimensões da imagem para os bboxes
import matplotlib.pyplot as plt # Para visualização de bboxes
import matplotlib.patches as patches # Para desenhar retângulos
import cv2 # Usado na seção de verificação opcional, pode ser necessário para ler imagens

# %%
import os
import shutil

# --- Configurações de Caminho ---
FINAL_MERGED_IMAGE_DIR = "all_dataset_images" # Nome da pasta para juntar todas as imagens

# Certifica-se de que a pasta de destino final existe
if not os.path.exists(FINAL_MERGED_IMAGE_DIR):
    os.makedirs(FINAL_MERGED_IMAGE_DIR)
    print(f"Pasta de destino '{FINAL_MERGED_IMAGE_DIR}' criada.")

# Diretórios de onde as imagens serão COLETADAS
image_dirs = [
    'PART_1/PART_1/images',
    'PART_2/PART_2/images',
    'PART_3/PART_3/images'
]

# Extensões de arquivo de imagem que serão consideradas
IMAGE_EXTENSIONS = ('.jpg', '.jpeg', '.png')

# --- Processo de Junção de Imagens ---

print("\nIniciando a cópia das imagens...")
copied_image_count = 0

for source_dir in image_dirs:
    # Verifica se o diretório de origem existe antes de tentar listar
    if not os.path.exists(source_dir):
        print(f"Aviso: Diretório de origem '{source_dir}' não encontrado. Pulando...")
        continue

    print(f"Processando diretório: {source_dir}")
    for fname in os.listdir(source_dir):
        # Verifica se o arquivo é uma imagem pela extensão
        if fname.lower().endswith(IMAGE_EXTENSIONS):
            source_image_path = os.path.join(source_dir, fname)
            base_name, extension = os.path.splitext(fname)
            destination_image_name = f"{base_name}{extension}"
            destination_image_path = os.path.join(FINAL_MERGED_IMAGE_DIR, destination_image_name)

            try:
                shutil.copy2(source_image_path, destination_image_path)
                # print(f"Copiado: {source_image_path} -> {destination_image_path}")
                copied_image_count += 1
            except Exception as e:
                print(f"ERRO ao copiar '{source_image_path}': {e}")

print(f"\nProcesso concluído. Total de {copied_image_count} imagens copiadas para '{FINAL_MERGED_IMAGE_DIR}'.")

# %%
import os
import shutil

# --- Configurações de Caminho ---
FINAL_MERGED_ANNOTATION = "all_dataset_annotations" # Nome da pasta para juntar todas as anotações

# Certifica-se de que a pasta de destino final existe
if not os.path.exists(FINAL_MERGED_ANNOTATION):
    os.makedirs(FINAL_MERGED_ANNOTATION)
    print(f"Pasta de destino '{FINAL_MERGED_ANNOTATION}' criada.")

# Diretórios de onde as anotações serão COLETADAS
ANNOTATIONs = ['PART_1/PART_1/6categories']

# Extensões de arquivo de imagem que serão consideradas
ANNOTATIONs_EXTENSION = ('.txt')

# --- Processo de Junção de anotações ---

print("\nIniciando a cópia das anotações...")
copied_image_count = 0

for source_dir in ANNOTATIONs:
    # Verifica se o diretório de origem existe antes de tentar listar
    if not os.path.exists(source_dir):
        print(f"Aviso: Diretório de origem '{source_dir}' não encontrado. Pulando...")
        continue

    print(f"Processando diretório: {source_dir}")
    for fname in os.listdir(source_dir):
        # Verifica se o arquivo é uma imagem pela extensão
        if fname.lower().endswith(ANNOTATIONs_EXTENSION):
            source_image_path = os.path.join(source_dir, fname)
            base_name, extension = os.path.splitext(fname)
            destination_image_name = f"{base_name}{extension}"
            destination_image_path = os.path.join(FINAL_MERGED_ANNOTATION, destination_image_name)

            try:
                shutil.copy2(source_image_path, destination_image_path)
                # print(f"Copiado: {source_image_path} -> {destination_image_path}")
                copied_image_count += 1
            except Exception as e:
                print(f"ERRO ao copiar '{source_image_path}': {e}")

print(f"\nProcesso concluído. Total de {copied_image_count} anotações copiadas para '{FINAL_MERGED_ANNOTATION}'.")

# %%
import os

# Define o caminho para a pasta de anotações e o arquivo de nomes das classes
annotations_dir = "all_dataset_annotations"
names_file = "PART_1/PART_1/6categories.names"
# Sugiro um novo nome para o diretório de saída para não sobrescrever o anterior
output_dir = "cleaned_dataset_annotations_no_bouy" 

# Cria o diretório de saída se não existir
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 1. Ler o arquivo de nomes das classes para mapear nomes para índices
class_names = []
with open(names_file, 'r') as f:
    class_names = [line.strip() for line in f.readlines()]

# 2. Identificar o índice da classe a ser REMOVIDA ("bouy")
bouy_idx = -1
try:
    bouy_idx = class_names.index("bouy")
except ValueError:
    print(f"Erro: A classe 'bouy' não foi encontrada em {names_file}.")
    print(f"Classes lidas: {class_names}")
    exit()

print(f"Índice da classe 'bouy' a ser removida: {bouy_idx}")
print(f"Todas as outras classes serão mantidas: {', '.join([name for i, name in enumerate(class_names) if i != bouy_idx])}")

# 3. Iterar sobre cada arquivo de anotação no diretório
for filename in os.listdir(annotations_dir):
    if filename.endswith(".txt"):
        input_filepath = os.path.join(annotations_dir, filename)
        output_filepath = os.path.join(output_dir, filename)
        
        kept_annotations = [] # Renomeado para maior clareza
        
        with open(input_filepath, 'r') as infile:
            for line in infile:
                parts = line.strip().split()
                if not parts:
                    continue
                
                try:
                    class_id = int(parts[0])
                    # Manter a linha APENAS SE a classe NÃO FOR 'bouy'
                    if class_id != bouy_idx:
                        kept_annotations.append(line)
                except ValueError:
                    print(f"Aviso: Linha inválida ignorada em {filename}: {line.strip()}")
                    continue
        
        # 4. Escrever as anotações filtradas em um novo arquivo
        if kept_annotations:
            with open(output_filepath, 'w') as outfile:
                for annotation in kept_annotations:
                    outfile.write(annotation)
            print(f"Arquivo filtrado salvo em: {output_filepath}")
        else:
            # Isso pode acontecer se um arquivo SÓ tinha anotações de 'bouy'
            print(f"Nenhuma anotação mantida para o arquivo: {filename} (após remover 'bouy'). Nenhum arquivo de saída gerado.")

print("\nLimpeza (remoção de 'bouy') concluída!")

# %%
import os

# --- Configurações ---
# Diretório com TODAS as imagens (com base no seu notebook, parece ser este)
images_dir = "all_dataset_images" 

# Diretório com as anotações JÁ LIMPAS (o resultado do seu script anterior)
annotations_dir = "cleaned_dataset_annotations_no_bouy"

# --- Lógica do Script ---

# 1. Obter a lista de nomes base das anotações existentes
# Usamos um 'set' para uma busca muito mais rápida
annotation_basenames = set()
for ann_file in os.listdir(annotations_dir):
    if ann_file.endswith(".txt"):
        # Pega o nome do arquivo sem a extensão .txt (ex: 'img_001')
        basename = os.path.splitext(ann_file)[0]
        annotation_basenames.add(basename)

print(f"Encontradas {len(annotation_basenames)} anotações limpas em '{annotations_dir}'.")

# 2. Identificar imagens que não têm uma anotação correspondente
images_to_delete = []
for img_file in os.listdir(images_dir):
    # Pega o nome do arquivo de imagem sem a extensão (ex: 'img_001')
    img_basename = os.path.splitext(img_file)[0]
    
    # Se o nome base da imagem NÃO está na lista de nomes de anotações, ela deve ser apagada
    if img_basename not in annotation_basenames:
        images_to_delete.append(os.path.join(images_dir, img_file))

# 3. Revisão e Confirmação (PASSO DE SEGURANÇA)
if not images_to_delete:
    print("\nNenhuma imagem para apagar. Todas as imagens têm anotações correspondentes.")
else:
    print(f"\nAs seguintes {len(images_to_delete)} imagens serão APAGADAS pois não possuem anotações:")
    print(images_to_delete)
    # Mostra as primeiras 10 imagens para o usuário ter uma ideia
    for i, image_path in enumerate(images_to_delete[:10]):
        print(f" - {os.path.basename(image_path)}")
    if len(images_to_delete) > 10:
        print(f"   ... e mais {len(images_to_delete) - 10} outras.")

    # Pede confirmação ao usuário antes de apagar qualquer coisa
    # Mude para 's' se seu sistema for em português
    user_input = input("\nVocê tem certeza que deseja apagar esses arquivos? (s/n): ").lower()
    
    # 4. Apagar os arquivos se confirmado
    if user_input == 's' or user_input == 'y':
        deleted_count = 0
        for image_path in images_to_delete:
            try:
                os.remove(image_path)
                deleted_count += 1
            except OSError as e:
                print(f"Erro ao apagar o arquivo {image_path}: {e}")
        
        print(f"\nProcesso concluído. {deleted_count} imagens foram apagadas.")
    else:
        print("\nOperação cancelada pelo usuário. Nenhum arquivo foi apagado.")

# %%
import os

# --- Configurações de Caminho ---
input_dir = "cleaned_dataset_annotations_no_bouy"  # Pasta com anotações sem bouy
output_dir = "remapped_annotations"  # Nova pasta com classes remapeadas

# Cria o diretório de saída se não existir
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Pasta de destino '{output_dir}' criada.")

# --- Mapeamento de Classes ---
# Classes originais: human(0), wind-sup-board(1), boat(2), sailboat(4), kayak(5)
# Após remapeamento: human(0), boat(2)

class_mapping = {
    0: 0,  # human -> human (mantém)
    1: 0,  # wind-sup-board -> human  
    2: 2,  # boat -> boat (mantém)
    4: 2,  # sailboat -> boat
    5: 2   # kayak -> boat
}

print("Mapeamento de classes:")
print("  human (0) -> human (0)")
print("  wind-sup-board (1) -> human (0)")
print("  boat (2) -> boat (2)")
print("  sailboat (4) -> boat (2)")
print("  kayak (5) -> boat (2)")

# --- Processar arquivos ---
processed_files = 0
total_remapped_annotations = 0

for filename in os.listdir(input_dir):
    if filename.endswith(".txt"):
        input_filepath = os.path.join(input_dir, filename)
        output_filepath = os.path.join(output_dir, filename)
        
        remapped_annotations = []
        file_remapped_count = 0
        
        with open(input_filepath, 'r') as infile:
            for line in infile:
                parts = line.strip().split()
                if not parts:
                    continue
                
                try:
                    original_class_id = int(parts[0])
                    
                    # Verificar se a classe existe no mapeamento
                    if original_class_id in class_mapping:
                        new_class_id = class_mapping[original_class_id]
                        
                        # Se a classe mudou, contar como remapeada
                        if original_class_id != new_class_id:
                            file_remapped_count += 1
                            total_remapped_annotations += 1
                        
                        # Substituir o ID da classe
                        parts[0] = str(new_class_id)
                        
                        # Adicionar a linha processada
                        remapped_annotations.append(' '.join(parts) + '\n')
                    else:
                        print(f"Aviso: Classe {original_class_id} não encontrada no mapeamento em {filename}")
                        
                except ValueError:
                    print(f"Aviso: Linha inválida ignorada em {filename}: {line.strip()}")
                    continue
        
        # Escrever arquivo de saída
        if remapped_annotations:
            with open(output_filepath, 'w') as outfile:
                for annotation in remapped_annotations:
                    outfile.write(annotation)
            
            if file_remapped_count > 0:
                print(f"Arquivo {filename}: {file_remapped_count} anotações remapeadas")
        
        processed_files += 1

print(f"\nEtapa 1 concluída!")
print(f"  - {processed_files} arquivos processados")
print(f"  - {total_remapped_annotations} anotações remapeadas no total")
print(f"  - Arquivos salvos em: {output_dir}")
print(f"  - Agora você tem apenas classes: human (0) e boat (2)")
# Out:
# Pasta de destino 'remapped_annotations' criada.
# Mapeamento de classes:
#   human (0) -> human (0)
#   wind-sup-board (1) -> human (0)
#   boat (2) -> boat (2)
#   sailboat (4) -> boat (2)
#   kayak (5) -> boat (2)
# Arquivo av_1381.txt: 6 anotações remapeadas
# Arquivo av_249.txt: 2 anotações remapeadas
# Arquivo a_101.txt: 2 anotações remapeadas
# Arquivo a_1013.txt: 6 anotações remapeadas
# Arquivo a_1014.txt: 6 anotações remapeadas
# Arquivo a_1015.txt: 6 anotações remapeadas
# Arquivo a_1016.txt: 6 anotações remapeadas
# Arquivo a_1017.txt: 6 anotações remapeadas
# Arquivo a_1018.txt: 6 anotações remapeadas
# Arquivo a_1019.txt: 6 anotações remapeadas
# Arquivo a_102.txt: 2 anotações remapeadas
# Arquivo a_1020.txt: 6 anotações remapeadas
# Arquivo a_1021.txt: 6 anotações remapeadas
# Arquivo a_1022.txt: 6 anotações remapeadas
# Arquivo a_1023.txt: 6 anotações remapeadas
# Arquivo a_1024.txt: 6 anotações remapeadas
# Arquivo a_1025.txt: 6 anotações remapeadas
# Arquivo a_1026.txt: 6 anotações remapeadas
# Arquivo a_1027.txt: 6 anotações remapeadas
# Arquivo a_1028.txt: 6 anotações remapeadas
# Arquivo a_1029.txt: 6 anotações remapeadas
# Arquivo a_103.txt: 2 anotações remapeadas
# Arquivo a_1030.txt: 6 anotações remapeadas
# Arquivo a_1031.txt: 6 anotações remapeadas
# Arquivo a_1032.txt: 6 anotações remapeadas
# Arquivo a_1033.txt: 6 anotações remapeadas
# Arquivo a_1034.txt: 6 anotações remapeadas
# Arquivo a_1035.txt: 6 anotações remapeadas
# Arquivo a_1036.txt: 6 anotações remapeadas
# Arquivo a_1037.txt: 6 anotações remapeadas
# Arquivo a_1038.txt: 6 anotações remapeadas
# Arquivo a_1039.txt: 6 anotações remapeadas
# Arquivo a_104.txt: 1 anotações remapeadas
# Arquivo a_1040.txt: 6 anotações remapeadas
# Arquivo a_1041.txt: 6 anotações remapeadas
# Arquivo a_1042.txt: 6 anotações remapeadas
# Arquivo a_1043.txt: 6 anotações remapeadas
# Arquivo a_1044.txt: 6 anotações remapeadas
# Arquivo a_1045.txt: 6 anotações remapeadas
# Arquivo a_1046.txt: 6 anotações remapeadas
# Arquivo a_1047.txt: 6 anotações remapeadas
# Arquivo a_1048.txt: 6 anotações remapeadas
# Arquivo a_1049.txt: 6 anotações remapeadas
# Arquivo a_105.txt: 1 anotações remapeadas
# Arquivo a_1050.txt: 6 anotações remapeadas
# Arquivo a_1051.txt: 6 anotações remapeadas
# Arquivo a_1052.txt: 6 anotações remapeadas
# Arquivo a_1053.txt: 6 anotações remapeadas
# Arquivo a_1054.txt: 6 anotações remapeadas
# Arquivo a_1055.txt: 6 anotações remapeadas
# Arquivo a_1056.txt: 5 anotações remapeadas
# Arquivo a_1057.txt: 4 anotações remapeadas
# Arquivo a_1058.txt: 4 anotações remapeadas
# Arquivo a_1059.txt: 4 anotações remapeadas
# Arquivo a_1060.txt: 4 anotações remapeadas
# Arquivo a_1061.txt: 4 anotações remapeadas
# Arquivo a_1062.txt: 3 anotações remapeadas
# Arquivo a_1063.txt: 2 anotações remapeadas
# Arquivo a_1064.txt: 2 anotações remapeadas
# Arquivo a_1065.txt: 2 anotações remapeadas
# Arquivo a_1066.txt: 2 anotações remapeadas
# Arquivo a_1067.txt: 2 anotações remapeadas
# Arquivo a_1068.txt: 2 anotações remapeadas
# Arquivo a_1069.txt: 2 anotações remapeadas
# Arquivo a_1070.txt: 1 anotações remapeadas
# Arquivo a_1084.txt: 2 anotações remapeadas
# Arquivo a_1085.txt: 2 anotações remapeadas
# Arquivo a_1086.txt: 2 anotações remapeadas
# Arquivo a_1087.txt: 2 anotações remapeadas
# Arquivo a_1088.txt: 4 anotações remapeadas
# Arquivo a_1089.txt: 4 anotações remapeadas
# Arquivo a_1090.txt: 4 anotações remapeadas
# Arquivo a_1091.txt: 4 anotações remapeadas
# Arquivo a_1092.txt: 5 anotações remapeadas
# Arquivo a_1093.txt: 6 anotações remapeadas
# Arquivo a_1094.txt: 6 anotações remapeadas
# Arquivo a_1095.txt: 6 anotações remapeadas
# Arquivo a_1096.txt: 6 anotações remapeadas
# Arquivo a_1097.txt: 6 anotações remapeadas
# Arquivo a_1098.txt: 6 anotações remapeadas
# Arquivo a_1099.txt: 6 anotações remapeadas
# Arquivo a_1100.txt: 6 anotações remapeadas
# Arquivo a_1101.txt: 6 anotações remapeadas
# Arquivo a_1102.txt: 6 anotações remapeadas
# Arquivo a_1103.txt: 6 anotações remapeadas
# Arquivo a_1104.txt: 6 anotações remapeadas
# Arquivo a_1105.txt: 6 anotações remapeadas
# Arquivo a_1106.txt: 6 anotações remapeadas
# Arquivo a_1107.txt: 6 anotações remapeadas
# Arquivo a_1108.txt: 6 anotações remapeadas
# Arquivo a_1109.txt: 6 anotações remapeadas
# Arquivo a_1110.txt: 6 anotações remapeadas
# Arquivo a_1111.txt: 6 anotações remapeadas
# Arquivo a_1112.txt: 6 anotações remapeadas
# Arquivo a_1113.txt: 6 anotações remapeadas
# Arquivo a_1114.txt: 6 anotações remapeadas
# Arquivo a_1115.txt: 6 anotações remapeadas
# Arquivo a_1116.txt: 6 anotações remapeadas
# Arquivo a_1117.txt: 6 anotações remapeadas
# Arquivo a_1118.txt: 6 anotações remapeadas
# Arquivo a_1119.txt: 6 anotações remapeadas
# Arquivo a_1120.txt: 6 anotações remapeadas
# Arquivo a_1121.txt: 6 anotações remapeadas
# Arquivo a_1122.txt: 6 anotações remapeadas
# Arquivo a_1123.txt: 6 anotações remapeadas
# Arquivo a_1124.txt: 6 anotações remapeadas
# Arquivo a_1125.txt: 6 anotações remapeadas
# Arquivo a_1126.txt: 6 anotações remapeadas
# Arquivo a_1127.txt: 6 anotações remapeadas
# Arquivo a_1128.txt: 6 anotações remapeadas
# Arquivo a_1129.txt: 6 anotações remapeadas
# Arquivo a_1130.txt: 6 anotações remapeadas
# Arquivo a_1131.txt: 6 anotações remapeadas
# Arquivo a_1132.txt: 6 anotações remapeadas
# Arquivo a_1133.txt: 6 anotações remapeadas
# Arquivo a_1134.txt: 6 anotações remapeadas
# Arquivo a_1135.txt: 6 anotações remapeadas
# Arquivo a_1136.txt: 6 anotações remapeadas
# Arquivo a_1137.txt: 6 anotações remapeadas
# Arquivo a_1138.txt: 6 anotações remapeadas
# Arquivo a_1139.txt: 6 anotações remapeadas
# Arquivo a_1140.txt: 6 anotações remapeadas
# Arquivo a_1141.txt: 6 anotações remapeadas
# Arquivo a_1142.txt: 6 anotações remapeadas
# Arquivo a_1143.txt: 6 anotações remapeadas
# Arquivo a_1144.txt: 6 anotações remapeadas
# Arquivo a_1145.txt: 6 anotações remapeadas
# Arquivo a_1146.txt: 6 anotações remapeadas
# Arquivo a_1147.txt: 6 anotações remapeadas
# Arquivo a_1148.txt: 6 anotações remapeadas
# Arquivo a_1149.txt: 6 anotações remapeadas
# Arquivo a_1150.txt: 6 anotações remapeadas
# Arquivo a_1151.txt: 6 anotações remapeadas
# Arquivo a_1152.txt: 6 anotações remapeadas
# Arquivo a_1153.txt: 6 anotações remapeadas
# Arquivo a_1154.txt: 6 anotações remapeadas
# Arquivo a_1155.txt: 6 anotações remapeadas
# Arquivo a_1156.txt: 6 anotações remapeadas
# Arquivo a_1157.txt: 6 anotações remapeadas
# Arquivo a_1158.txt: 6 anotações remapeadas
# Arquivo a_1159.txt: 6 anotações remapeadas
# Arquivo a_1160.txt: 6 anotações remapeadas
# Arquivo a_1161.txt: 6 anotações remapeadas
# Arquivo a_1162.txt: 6 anotações remapeadas
# Arquivo a_1163.txt: 6 anotações remapeadas
# Arquivo a_1164.txt: 6 anotações remapeadas
# Arquivo a_1165.txt: 6 anotações remapeadas
# Arquivo a_1166.txt: 6 anotações remapeadas
# Arquivo a_1167.txt: 6 anotações remapeadas
# Arquivo a_1168.txt: 6 anotações remapeadas
# Arquivo a_1169.txt: 6 anotações remapeadas
# Arquivo a_1170.txt: 6 anotações remapeadas
# Arquivo a_1171.txt: 6 anotações remapeadas
# Arquivo a_1172.txt: 6 anotações remapeadas
# Arquivo a_1173.txt: 6 anotações remapeadas
# Arquivo a_1174.txt: 6 anotações remapeadas
# Arquivo a_1175.txt: 6 anotações remapeadas
# Arquivo a_1176.txt: 6 anotações remapeadas
# Arquivo a_1177.txt: 6 anotações remapeadas
# Arquivo a_1178.txt: 6 anotações remapeadas
# Arquivo a_1179.txt: 6 anotações remapeadas
# Arquivo a_1180.txt: 6 anotações remapeadas
# Arquivo a_1181.txt: 6 anotações remapeadas
# Arquivo a_1182.txt: 6 anotações remapeadas
# Arquivo a_1183.txt: 6 anotações remapeadas
# Arquivo a_1184.txt: 6 anotações remapeadas
# Arquivo a_1185.txt: 6 anotações remapeadas
# Arquivo a_1186.txt: 6 anotações remapeadas
# Arquivo a_1187.txt: 6 anotações remapeadas
# Arquivo a_1188.txt: 6 anotações remapeadas
# Arquivo a_1189.txt: 6 anotações remapeadas
# Arquivo a_1190.txt: 6 anotações remapeadas
# Arquivo a_1191.txt: 6 anotações remapeadas
# Arquivo a_1192.txt: 6 anotações remapeadas
# Arquivo a_1193.txt: 6 anotações remapeadas
# Arquivo a_1194.txt: 6 anotações remapeadas
# Arquivo a_1195.txt: 6 anotações remapeadas
# Arquivo a_1196.txt: 6 anotações remapeadas
# Arquivo a_1197.txt: 6 anotações remapeadas
# Arquivo a_1198.txt: 6 anotações remapeadas
# Arquivo a_1199.txt: 6 anotações remapeadas
# Arquivo a_1200.txt: 6 anotações remapeadas
# Arquivo a_1201.txt: 6 anotações remapeadas
# Arquivo a_1202.txt: 6 anotações remapeadas
# Arquivo a_1203.txt: 6 anotações remapeadas
# Arquivo a_1204.txt: 6 anotações remapeadas
# Arquivo a_1205.txt: 6 anotações remapeadas
# Arquivo a_1206.txt: 6 anotações remapeadas
# Arquivo a_1207.txt: 6 anotações remapeadas
# Arquivo a_1208.txt: 6 anotações remapeadas
# Arquivo a_1209.txt: 6 anotações remapeadas
# Arquivo a_1210.txt: 6 anotações remapeadas
# Arquivo a_1211.txt: 6 anotações remapeadas
# Arquivo a_1212.txt: 6 anotações remapeadas
# Arquivo a_1213.txt: 6 anotações remapeadas
# Arquivo a_1214.txt: 6 anotações remapeadas
# Arquivo a_1215.txt: 6 anotações remapeadas
# Arquivo a_1216.txt: 6 anotações remapeadas
# Arquivo a_1217.txt: 6 anotações remapeadas
# Arquivo a_1218.txt: 6 anotações remapeadas
# Arquivo a_1219.txt: 6 anotações remapeadas
# Arquivo a_1220.txt: 6 anotações remapeadas
# Arquivo a_1221.txt: 6 anotações remapeadas
# Arquivo a_1222.txt: 6 anotações remapeadas
# Arquivo a_1223.txt: 6 anotações remapeadas
# Arquivo a_1224.txt: 6 anotações remapeadas
# Arquivo a_1225.txt: 6 anotações remapeadas
# Arquivo a_1226.txt: 6 anotações remapeadas
# Arquivo a_1227.txt: 6 anotações remapeadas
# Arquivo a_1228.txt: 6 anotações remapeadas
# Arquivo a_1229.txt: 6 anotações remapeadas
# Arquivo a_1230.txt: 6 anotações remapeadas
# Arquivo a_1231.txt: 6 anotações remapeadas
# Arquivo a_1232.txt: 6 anotações remapeadas
# Arquivo a_1233.txt: 6 anotações remapeadas
# Arquivo a_1234.txt: 6 anotações remapeadas
# Arquivo a_1235.txt: 6 anotações remapeadas
# Arquivo a_1236.txt: 6 anotações remapeadas
# Arquivo a_1237.txt: 6 anotações remapeadas
# Arquivo a_1238.txt: 6 anotações remapeadas
# Arquivo a_1239.txt: 6 anotações remapeadas
# Arquivo a_1240.txt: 6 anotações remapeadas
# Arquivo a_1241.txt: 6 anotações remapeadas
# Arquivo a_1242.txt: 6 anotações remapeadas
# Arquivo a_1243.txt: 6 anotações remapeadas
# Arquivo a_1244.txt: 6 anotações remapeadas
# Arquivo a_1245.txt: 6 anotações remapeadas
# Arquivo a_1246.txt: 6 anotações remapeadas
# Arquivo a_1247.txt: 6 anotações remapeadas
# Arquivo a_1248.txt: 6 anotações remapeadas
# Arquivo a_1249.txt: 6 anotações remapeadas
# Arquivo a_1250.txt: 6 anotações remapeadas
# Arquivo a_1251.txt: 6 anotações remapeadas
# Arquivo a_1252.txt: 6 anotações remapeadas
# Arquivo a_1253.txt: 6 anotações remapeadas
# Arquivo a_1254.txt: 6 anotações remapeadas
# Arquivo a_1255.txt: 6 anotações remapeadas
# Arquivo a_1256.txt: 6 anotações remapeadas
# Arquivo a_1257.txt: 6 anotações remapeadas
# Arquivo a_1258.txt: 6 anotações remapeadas
# Arquivo a_1259.txt: 6 anotações remapeadas
# Arquivo a_1260.txt: 6 anotações remapeadas
# Arquivo a_1261.txt: 6 anotações remapeadas
# Arquivo a_1262.txt: 6 anotações remapeadas
# Arquivo a_1263.txt: 6 anotações remapeadas
# Arquivo a_1264.txt: 6 anotações remapeadas
# Arquivo a_164.txt: 1 anotações remapeadas
# Arquivo a_165.txt: 1 anotações remapeadas
# Arquivo a_166.txt: 1 anotações remapeadas
# Arquivo a_167.txt: 1 anotações remapeadas
# Arquivo a_168.txt: 1 anotações remapeadas
# Arquivo a_169.txt: 1 anotações remapeadas
# Arquivo a_170.txt: 1 anotações remapeadas
# Arquivo a_171.txt: 1 anotações remapeadas
# Arquivo a_172.txt: 1 anotações remapeadas
# Arquivo a_173.txt: 1 anotações remapeadas
# Arquivo a_174.txt: 1 anotações remapeadas
# Arquivo a_175.txt: 2 anotações remapeadas
# Arquivo a_176.txt: 1 anotações remapeadas
# Arquivo a_178.txt: 1 anotações remapeadas
# Arquivo a_179.txt: 1 anotações remapeadas
# Arquivo a_187.txt: 1 anotações remapeadas
# Arquivo a_188.txt: 1 anotações remapeadas
# Arquivo a_301.txt: 5 anotações remapeadas
# Arquivo a_302.txt: 5 anotações remapeadas
# Arquivo a_303.txt: 5 anotações remapeadas
# Arquivo a_304.txt: 5 anotações remapeadas
# Arquivo a_305.txt: 5 anotações remapeadas
# Arquivo a_306.txt: 4 anotações remapeadas
# Arquivo a_307.txt: 4 anotações remapeadas
# Arquivo a_308.txt: 4 anotações remapeadas
# Arquivo a_309.txt: 4 anotações remapeadas
# Arquivo a_310.txt: 5 anotações remapeadas
# Arquivo a_311.txt: 5 anotações remapeadas
# Arquivo a_312.txt: 5 anotações remapeadas
# Arquivo a_313.txt: 5 anotações remapeadas
# Arquivo a_314.txt: 5 anotações remapeadas
# Arquivo a_315.txt: 5 anotações remapeadas
# Arquivo a_316.txt: 5 anotações remapeadas
# Arquivo a_317.txt: 5 anotações remapeadas
# Arquivo a_318.txt: 5 anotações remapeadas
# Arquivo a_319.txt: 5 anotações remapeadas
# Arquivo a_320.txt: 5 anotações remapeadas
# Arquivo a_321.txt: 5 anotações remapeadas
# Arquivo a_322.txt: 5 anotações remapeadas
# Arquivo a_323.txt: 5 anotações remapeadas
# Arquivo a_324.txt: 5 anotações remapeadas
# Arquivo a_325.txt: 5 anotações remapeadas
# Arquivo a_326.txt: 5 anotações remapeadas
# Arquivo a_327.txt: 5 anotações remapeadas
# Arquivo a_328.txt: 5 anotações remapeadas
# Arquivo a_329.txt: 5 anotações remapeadas
# Arquivo a_330.txt: 5 anotações remapeadas
# Arquivo a_331.txt: 5 anotações remapeadas
# Arquivo a_332.txt: 5 anotações remapeadas
# Arquivo a_333.txt: 6 anotações remapeadas
# Arquivo a_334.txt: 6 anotações remapeadas
# Arquivo a_335.txt: 6 anotações remapeadas
# Arquivo a_336.txt: 6 anotações remapeadas
# Arquivo a_337.txt: 6 anotações remapeadas
# Arquivo a_338.txt: 6 anotações remapeadas
# Arquivo a_339.txt: 6 anotações remapeadas
# Arquivo a_340.txt: 6 anotações remapeadas
# Arquivo a_341.txt: 6 anotações remapeadas
# Arquivo a_342.txt: 6 anotações remapeadas
# Arquivo a_343.txt: 6 anotações remapeadas
# Arquivo a_344.txt: 6 anotações remapeadas
# Arquivo a_345.txt: 6 anotações remapeadas
# Arquivo a_346.txt: 6 anotações remapeadas
# Arquivo a_347.txt: 5 anotações remapeadas
# Arquivo a_348.txt: 5 anotações remapeadas
# Arquivo a_349.txt: 5 anotações remapeadas
# Arquivo a_350.txt: 5 anotações remapeadas
# Arquivo a_351.txt: 4 anotações remapeadas
# Arquivo a_352.txt: 4 anotações remapeadas
# Arquivo a_353.txt: 4 anotações remapeadas
# Arquivo a_354.txt: 4 anotações remapeadas
# Arquivo a_355.txt: 4 anotações remapeadas
# Arquivo a_356.txt: 3 anotações remapeadas
# Arquivo a_357.txt: 3 anotações remapeadas
# Arquivo a_358.txt: 3 anotações remapeadas
# Arquivo a_359.txt: 3 anotações remapeadas
# Arquivo a_360.txt: 3 anotações remapeadas
# Arquivo a_361.txt: 3 anotações remapeadas
# Arquivo a_362.txt: 3 anotações remapeadas
# Arquivo a_363.txt: 3 anotações remapeadas
# Arquivo a_364.txt: 3 anotações remapeadas
# Arquivo a_365.txt: 3 anotações remapeadas
# Arquivo a_366.txt: 3 anotações remapeadas
# Arquivo a_367.txt: 3 anotações remapeadas
# Arquivo a_368.txt: 3 anotações remapeadas
# Arquivo a_369.txt: 3 anotações remapeadas
# Arquivo a_370.txt: 3 anotações remapeadas
# Arquivo a_371.txt: 2 anotações remapeadas
# Arquivo a_372.txt: 2 anotações remapeadas
# Arquivo a_373.txt: 2 anotações remapeadas
# Arquivo a_374.txt: 2 anotações remapeadas
# Arquivo a_375.txt: 2 anotações remapeadas
# Arquivo a_376.txt: 2 anotações remapeadas
# Arquivo a_377.txt: 2 anotações remapeadas
# Arquivo a_378.txt: 2 anotações remapeadas
# Arquivo a_379.txt: 2 anotações remapeadas
# Arquivo a_380.txt: 2 anotações remapeadas
# Arquivo a_381.txt: 2 anotações remapeadas
# Arquivo a_382.txt: 2 anotações remapeadas
# Arquivo a_383.txt: 2 anotações remapeadas
# Arquivo a_384.txt: 2 anotações remapeadas
# Arquivo a_385.txt: 2 anotações remapeadas
# Arquivo a_386.txt: 2 anotações remapeadas
# Arquivo a_387.txt: 2 anotações remapeadas
# Arquivo a_388.txt: 2 anotações remapeadas
# Arquivo a_389.txt: 2 anotações remapeadas
# Arquivo a_390.txt: 2 anotações remapeadas
# Arquivo a_391.txt: 2 anotações remapeadas
# Arquivo a_392.txt: 2 anotações remapeadas
# Arquivo a_393.txt: 2 anotações remapeadas
# Arquivo a_394.txt: 2 anotações remapeadas
# Arquivo a_395.txt: 2 anotações remapeadas
# Arquivo a_396.txt: 1 anotações remapeadas
# Arquivo a_397.txt: 1 anotações remapeadas
# Arquivo a_398.txt: 1 anotações remapeadas
# Arquivo a_399.txt: 1 anotações remapeadas
# Arquivo a_400.txt: 1 anotações remapeadas
# Arquivo a_401.txt: 1 anotações remapeadas
# Arquivo a_402.txt: 1 anotações remapeadas
# Arquivo a_403.txt: 1 anotações remapeadas
# Arquivo a_404.txt: 1 anotações remapeadas
# Arquivo a_405.txt: 1 anotações remapeadas
# Arquivo a_406.txt: 1 anotações remapeadas
# Arquivo a_407.txt: 1 anotações remapeadas
# Arquivo a_408.txt: 1 anotações remapeadas
# Arquivo a_409.txt: 1 anotações remapeadas
# Arquivo a_410.txt: 1 anotações remapeadas
# Arquivo a_411.txt: 1 anotações remapeadas
# Arquivo a_412.txt: 1 anotações remapeadas
# Arquivo b1_101.txt: 1 anotações remapeadas
# Arquivo b1_102.txt: 1 anotações remapeadas
# Arquivo b1_103.txt: 1 anotações remapeadas
# Arquivo b1_104.txt: 3 anotações remapeadas
# Arquivo b1_105.txt: 4 anotações remapeadas
# Arquivo b1_106.txt: 6 anotações remapeadas
# Arquivo b1_107.txt: 6 anotações remapeadas
# Arquivo b1_108.txt: 6 anotações remapeadas
# Arquivo b1_109.txt: 4 anotações remapeadas
# Arquivo b1_11.txt: 6 anotações remapeadas
# Arquivo b1_110.txt: 4 anotações remapeadas
# Arquivo b1_111.txt: 4 anotações remapeadas
# Arquivo b1_112.txt: 4 anotações remapeadas
# Arquivo b1_113.txt: 4 anotações remapeadas
# Arquivo b1_114.txt: 4 anotações remapeadas
# Arquivo b1_115.txt: 4 anotações remapeadas
# Arquivo b1_116.txt: 4 anotações remapeadas
# Arquivo b1_117.txt: 4 anotações remapeadas
# Arquivo b1_118.txt: 4 anotações remapeadas
# Arquivo b1_119.txt: 4 anotações remapeadas
# Arquivo b1_12.txt: 6 anotações remapeadas
# Arquivo b1_120.txt: 5 anotações remapeadas
# Arquivo b1_121.txt: 6 anotações remapeadas
# Arquivo b1_122.txt: 5 anotações remapeadas
# Arquivo b1_123.txt: 5 anotações remapeadas
# Arquivo b1_124.txt: 5 anotações remapeadas
# Arquivo b1_125.txt: 5 anotações remapeadas
# Arquivo b1_126.txt: 5 anotações remapeadas
# Arquivo b1_127.txt: 2 anotações remapeadas
# Arquivo b1_128.txt: 1 anotações remapeadas
# Arquivo b1_129.txt: 1 anotações remapeadas
# Arquivo b1_13.txt: 6 anotações remapeadas
# Arquivo b1_130.txt: 1 anotações remapeadas
# Arquivo b1_131.txt: 2 anotações remapeadas
# Arquivo b1_132.txt: 1 anotações remapeadas
# Arquivo b1_133.txt: 1 anotações remapeadas
# Arquivo b1_134.txt: 1 anotações remapeadas
# Arquivo b1_135.txt: 2 anotações remapeadas
# Arquivo b1_136.txt: 1 anotações remapeadas
# Arquivo b1_137.txt: 1 anotações remapeadas
# Arquivo b1_138.txt: 1 anotações remapeadas
# Arquivo b1_139.txt: 1 anotações remapeadas
# Arquivo b1_14.txt: 6 anotações remapeadas
# Arquivo b1_140.txt: 1 anotações remapeadas
# Arquivo b1_141.txt: 1 anotações remapeadas
# Arquivo b1_142.txt: 1 anotações remapeadas
# Arquivo b1_143.txt: 1 anotações remapeadas
# Arquivo b1_144.txt: 1 anotações remapeadas
# Arquivo b1_145.txt: 1 anotações remapeadas
# Arquivo b1_146.txt: 1 anotações remapeadas
# Arquivo b1_147.txt: 1 anotações remapeadas
# Arquivo b1_148.txt: 1 anotações remapeadas
# Arquivo b1_149.txt: 1 anotações remapeadas
# Arquivo b1_15.txt: 6 anotações remapeadas
# Arquivo b1_150.txt: 1 anotações remapeadas
# Arquivo b1_151.txt: 1 anotações remapeadas
# Arquivo b1_152.txt: 1 anotações remapeadas
# Arquivo b1_153.txt: 1 anotações remapeadas
# Arquivo b1_154.txt: 1 anotações remapeadas
# Arquivo b1_155.txt: 1 anotações remapeadas
# Arquivo b1_156.txt: 1 anotações remapeadas
# Arquivo b1_157.txt: 1 anotações remapeadas
# Arquivo b1_158.txt: 1 anotações remapeadas
# Arquivo b1_159.txt: 1 anotações remapeadas
# Arquivo b1_16.txt: 6 anotações remapeadas
# Arquivo b1_160.txt: 1 anotações remapeadas
# Arquivo b1_161.txt: 1 anotações remapeadas
# Arquivo b1_162.txt: 1 anotações remapeadas
# Arquivo b1_163.txt: 1 anotações remapeadas
# Arquivo b1_164.txt: 1 anotações remapeadas
# Arquivo b1_165.txt: 1 anotações remapeadas
# Arquivo b1_166.txt: 1 anotações remapeadas
# Arquivo b1_167.txt: 1 anotações remapeadas
# Arquivo b1_168.txt: 1 anotações remapeadas
# Arquivo b1_169.txt: 1 anotações remapeadas
# Arquivo b1_17.txt: 6 anotações remapeadas
# Arquivo b1_170.txt: 1 anotações remapeadas
# Arquivo b1_171.txt: 1 anotações remapeadas
# Arquivo b1_172.txt: 1 anotações remapeadas
# Arquivo b1_173.txt: 1 anotações remapeadas
# Arquivo b1_174.txt: 1 anotações remapeadas
# Arquivo b1_175.txt: 1 anotações remapeadas
# Arquivo b1_176.txt: 1 anotações remapeadas
# Arquivo b1_177.txt: 1 anotações remapeadas
# Arquivo b1_178.txt: 1 anotações remapeadas
# Arquivo b1_179.txt: 1 anotações remapeadas
# Arquivo b1_18.txt: 6 anotações remapeadas
# Arquivo b1_180.txt: 1 anotações remapeadas
# Arquivo b1_181.txt: 1 anotações remapeadas
# Arquivo b1_182.txt: 2 anotações remapeadas
# Arquivo b1_183.txt: 1 anotações remapeadas
# Arquivo b1_184.txt: 1 anotações remapeadas
# Arquivo b1_185.txt: 1 anotações remapeadas
# Arquivo b1_186.txt: 1 anotações remapeadas
# Arquivo b1_187.txt: 2 anotações remapeadas
# Arquivo b1_188.txt: 1 anotações remapeadas
# Arquivo b1_189.txt: 1 anotações remapeadas
# Arquivo b1_19.txt: 6 anotações remapeadas
# Arquivo b1_190.txt: 1 anotações remapeadas
# Arquivo b1_191.txt: 1 anotações remapeadas
# Arquivo b1_192.txt: 1 anotações remapeadas
# Arquivo b1_193.txt: 1 anotações remapeadas
# Arquivo b1_194.txt: 1 anotações remapeadas
# Arquivo b1_195.txt: 1 anotações remapeadas
# Arquivo b1_196.txt: 1 anotações remapeadas
# Arquivo b1_197.txt: 1 anotações remapeadas
# Arquivo b1_198.txt: 1 anotações remapeadas
# Arquivo b1_199.txt: 1 anotações remapeadas
# Arquivo b1_20.txt: 6 anotações remapeadas
# Arquivo b1_200.txt: 1 anotações remapeadas
# Arquivo b1_201.txt: 1 anotações remapeadas
# Arquivo b1_202.txt: 1 anotações remapeadas
# Arquivo b1_203.txt: 1 anotações remapeadas
# Arquivo b1_204.txt: 1 anotações remapeadas
# Arquivo b1_205.txt: 1 anotações remapeadas
# Arquivo b1_206.txt: 1 anotações remapeadas
# Arquivo b1_207.txt: 1 anotações remapeadas
# Arquivo b1_208.txt: 1 anotações remapeadas
# Arquivo b1_209.txt: 1 anotações remapeadas
# Arquivo b1_21.txt: 5 anotações remapeadas
# Arquivo b1_210.txt: 1 anotações remapeadas
# Arquivo b1_211.txt: 1 anotações remapeadas
# Arquivo b1_212.txt: 1 anotações remapeadas
# Arquivo b1_213.txt: 1 anotações remapeadas
# Arquivo b1_214.txt: 1 anotações remapeadas
# Arquivo b1_215.txt: 1 anotações remapeadas
# Arquivo b1_216.txt: 1 anotações remapeadas
# Arquivo b1_217.txt: 1 anotações remapeadas
# Arquivo b1_218.txt: 1 anotações remapeadas
# Arquivo b1_219.txt: 1 anotações remapeadas
# Arquivo b1_22.txt: 6 anotações remapeadas
# Arquivo b1_220.txt: 1 anotações remapeadas
# Arquivo b1_221.txt: 1 anotações remapeadas
# Arquivo b1_222.txt: 1 anotações remapeadas
# Arquivo b1_223.txt: 1 anotações remapeadas
# Arquivo b1_224.txt: 1 anotações remapeadas
# Arquivo b1_225.txt: 1 anotações remapeadas
# Arquivo b1_226.txt: 1 anotações remapeadas
# Arquivo b1_227.txt: 1 anotações remapeadas
# Arquivo b1_228.txt: 1 anotações remapeadas
# Arquivo b1_229.txt: 1 anotações remapeadas
# Arquivo b1_23.txt: 6 anotações remapeadas
# Arquivo b1_230.txt: 1 anotações remapeadas
# Arquivo b1_231.txt: 1 anotações remapeadas
# Arquivo b1_232.txt: 1 anotações remapeadas
# Arquivo b1_233.txt: 1 anotações remapeadas
# Arquivo b1_234.txt: 1 anotações remapeadas
# Arquivo b1_235.txt: 1 anotações remapeadas
# Arquivo b1_236.txt: 1 anotações remapeadas
# Arquivo b1_237.txt: 1 anotações remapeadas
# Arquivo b1_238.txt: 1 anotações remapeadas
# Arquivo b1_239.txt: 1 anotações remapeadas
# Arquivo b1_24.txt: 4 anotações remapeadas
# Arquivo b1_240.txt: 1 anotações remapeadas
# Arquivo b1_241.txt: 1 anotações remapeadas
# Arquivo b1_242.txt: 1 anotações remapeadas
# Arquivo b1_243.txt: 1 anotações remapeadas
# Arquivo b1_244.txt: 1 anotações remapeadas
# Arquivo b1_245.txt: 1 anotações remapeadas
# Arquivo b1_246.txt: 1 anotações remapeadas
# Arquivo b1_247.txt: 1 anotações remapeadas
# Arquivo b1_248.txt: 1 anotações remapeadas
# Arquivo b1_249.txt: 1 anotações remapeadas
# Arquivo b1_25.txt: 3 anotações remapeadas
# Arquivo b1_250.txt: 1 anotações remapeadas
# Arquivo b1_251.txt: 1 anotações remapeadas
# Arquivo b1_252.txt: 1 anotações remapeadas
# Arquivo b1_253.txt: 1 anotações remapeadas
# Arquivo b1_254.txt: 1 anotações remapeadas
# Arquivo b1_255.txt: 1 anotações remapeadas
# Arquivo b1_256.txt: 1 anotações remapeadas
# Arquivo b1_257.txt: 1 anotações remapeadas
# Arquivo b1_258.txt: 1 anotações remapeadas
# Arquivo b1_259.txt: 1 anotações remapeadas
# Arquivo b1_26.txt: 2 anotações remapeadas
# Arquivo b1_260.txt: 1 anotações remapeadas
# Arquivo b1_261.txt: 1 anotações remapeadas
# Arquivo b1_262.txt: 1 anotações remapeadas
# Arquivo b1_263.txt: 1 anotações remapeadas
# Arquivo b1_264.txt: 1 anotações remapeadas
# Arquivo b1_265.txt: 1 anotações remapeadas
# Arquivo b1_266.txt: 1 anotações remapeadas
# Arquivo b1_267.txt: 1 anotações remapeadas
# Arquivo b1_268.txt: 2 anotações remapeadas
# Arquivo b1_269.txt: 2 anotações remapeadas
# Arquivo b1_27.txt: 3 anotações remapeadas
# Arquivo b1_270.txt: 2 anotações remapeadas
# Arquivo b1_271.txt: 2 anotações remapeadas
# Arquivo b1_272.txt: 1 anotações remapeadas
# Arquivo b1_273.txt: 1 anotações remapeadas
# Arquivo b1_274.txt: 1 anotações remapeadas
# Arquivo b1_275.txt: 2 anotações remapeadas
# Arquivo b1_276.txt: 2 anotações remapeadas
# Arquivo b1_277.txt: 2 anotações remapeadas
# Arquivo b1_278.txt: 2 anotações remapeadas
# Arquivo b1_279.txt: 2 anotações remapeadas
# Arquivo b1_28.txt: 6 anotações remapeadas
# Arquivo b1_280.txt: 2 anotações remapeadas
# Arquivo b1_281.txt: 2 anotações remapeadas
# Arquivo b1_282.txt: 2 anotações remapeadas
# Arquivo b1_283.txt: 2 anotações remapeadas
# Arquivo b1_284.txt: 2 anotações remapeadas
# Arquivo b1_285.txt: 2 anotações remapeadas
# Arquivo b1_286.txt: 2 anotações remapeadas
# Arquivo b1_287.txt: 2 anotações remapeadas
# Arquivo b1_288.txt: 2 anotações remapeadas
# Arquivo b1_289.txt: 2 anotações remapeadas
# Arquivo b1_29.txt: 9 anotações remapeadas
# Arquivo b1_290.txt: 2 anotações remapeadas
# Arquivo b1_291.txt: 2 anotações remapeadas
# Arquivo b1_292.txt: 3 anotações remapeadas
# Arquivo b1_293.txt: 3 anotações remapeadas
# Arquivo b1_294.txt: 3 anotações remapeadas
# Arquivo b1_295.txt: 3 anotações remapeadas
# Arquivo b1_296.txt: 3 anotações remapeadas
# Arquivo b1_297.txt: 3 anotações remapeadas
# Arquivo b1_298.txt: 3 anotações remapeadas
# Arquivo b1_299.txt: 3 anotações remapeadas
# Arquivo b1_30.txt: 6 anotações remapeadas
# Arquivo b1_300.txt: 3 anotações remapeadas
# Arquivo b1_301.txt: 3 anotações remapeadas
# Arquivo b1_31.txt: 6 anotações remapeadas
# Arquivo b1_32.txt: 6 anotações remapeadas
# Arquivo b1_33.txt: 7 anotações remapeadas
# Arquivo b1_34.txt: 6 anotações remapeadas
# Arquivo b1_35.txt: 6 anotações remapeadas
# Arquivo b1_36.txt: 6 anotações remapeadas
# Arquivo b1_37.txt: 9 anotações remapeadas
# Arquivo b1_38.txt: 6 anotações remapeadas
# Arquivo b1_39.txt: 6 anotações remapeadas
# Arquivo b1_40.txt: 6 anotações remapeadas
# Arquivo b1_41.txt: 6 anotações remapeadas
# Arquivo b1_42.txt: 6 anotações remapeadas
# Arquivo b1_43.txt: 6 anotações remapeadas
# Arquivo b1_44.txt: 6 anotações remapeadas
# Arquivo b1_45.txt: 6 anotações remapeadas
# Arquivo b1_46.txt: 6 anotações remapeadas
# Arquivo b1_47.txt: 6 anotações remapeadas
# Arquivo b1_48.txt: 5 anotações remapeadas
# Arquivo b1_49.txt: 6 anotações remapeadas
# Arquivo b1_50.txt: 6 anotações remapeadas
# Arquivo b1_51.txt: 6 anotações remapeadas
# Arquivo b1_52.txt: 6 anotações remapeadas
# Arquivo b1_53.txt: 6 anotações remapeadas
# Arquivo b1_54.txt: 6 anotações remapeadas
# Arquivo b1_55.txt: 6 anotações remapeadas
# Arquivo b1_56.txt: 6 anotações remapeadas
# Arquivo b1_57.txt: 5 anotações remapeadas
# Arquivo b1_58.txt: 5 anotações remapeadas
# Arquivo b1_59.txt: 5 anotações remapeadas
# Arquivo b1_60.txt: 5 anotações remapeadas
# Arquivo b1_61.txt: 5 anotações remapeadas
# Arquivo b1_62.txt: 5 anotações remapeadas
# Arquivo b1_63.txt: 5 anotações remapeadas
# Arquivo b1_64.txt: 5 anotações remapeadas
# Arquivo b1_65.txt: 5 anotações remapeadas
# Arquivo b1_66.txt: 5 anotações remapeadas
# Arquivo b1_67.txt: 5 anotações remapeadas
# Arquivo b1_68.txt: 5 anotações remapeadas
# Arquivo b1_69.txt: 4 anotações remapeadas
# Arquivo b1_70.txt: 5 anotações remapeadas
# Arquivo b1_71.txt: 5 anotações remapeadas
# Arquivo b1_72.txt: 5 anotações remapeadas
# Arquivo b1_73.txt: 4 anotações remapeadas
# Arquivo b1_74.txt: 3 anotações remapeadas
# Arquivo b1_75.txt: 3 anotações remapeadas
# Arquivo b1_76.txt: 3 anotações remapeadas
# Arquivo b1_77.txt: 4 anotações remapeadas
# Arquivo b1_78.txt: 4 anotações remapeadas
# Arquivo b1_79.txt: 4 anotações remapeadas
# Arquivo b1_80.txt: 4 anotações remapeadas
# Arquivo b1_81.txt: 4 anotações remapeadas
# Arquivo b1_82.txt: 4 anotações remapeadas
# Arquivo b1_83.txt: 4 anotações remapeadas
# Arquivo b1_84.txt: 4 anotações remapeadas
# Arquivo b1_85.txt: 4 anotações remapeadas
# Arquivo b1_86.txt: 3 anotações remapeadas
# Arquivo b1_87.txt: 4 anotações remapeadas
# Arquivo b1_88.txt: 3 anotações remapeadas
# Arquivo b1_89.txt: 2 anotações remapeadas
# Arquivo b1_9.txt: 5 anotações remapeadas
# Arquivo b1_90.txt: 1 anotações remapeadas
# Arquivo b1_91.txt: 1 anotações remapeadas
# Arquivo b1_92.txt: 1 anotações remapeadas
# Arquivo b1_93.txt: 1 anotações remapeadas
# Arquivo b1_94.txt: 1 anotações remapeadas
# Arquivo b1_95.txt: 1 anotações remapeadas
# Arquivo b1_96.txt: 4 anotações remapeadas
# Arquivo b1_97.txt: 4 anotações remapeadas
# Arquivo b1_98.txt: 3 anotações remapeadas
# Arquivo b1_99.txt: 3 anotações remapeadas
# Arquivo b_100.txt: 1 anotações remapeadas
# Arquivo cv_1250.txt: 6 anotações remapeadas
# Arquivo cv_1503.txt: 6 anotações remapeadas
# Arquivo cv_338.txt: 1 anotações remapeadas
# Arquivo cv_590.txt: 4 anotações remapeadas
# Arquivo cv_857.txt: 6 anotações remapeadas
# Arquivo c_100.txt: 2 anotações remapeadas
# Arquivo c_101.txt: 2 anotações remapeadas
# Arquivo c_102.txt: 2 anotações remapeadas
# Arquivo c_103.txt: 2 anotações remapeadas
# Arquivo c_104.txt: 2 anotações remapeadas
# Arquivo c_105.txt: 2 anotações remapeadas
# Arquivo c_106.txt: 2 anotações remapeadas
# Arquivo c_107.txt: 2 anotações remapeadas
# Arquivo c_108.txt: 2 anotações remapeadas
# Arquivo c_109.txt: 2 anotações remapeadas
# Arquivo c_110.txt: 2 anotações remapeadas
# Arquivo c_111.txt: 2 anotações remapeadas
# Arquivo c_112.txt: 2 anotações remapeadas
# Arquivo c_113.txt: 2 anotações remapeadas
# Arquivo c_114.txt: 2 anotações remapeadas
# Arquivo c_115.txt: 2 anotações remapeadas
# Arquivo c_116.txt: 2 anotações remapeadas
# Arquivo c_117.txt: 2 anotações remapeadas
# Arquivo c_118.txt: 2 anotações remapeadas
# Arquivo c_119.txt: 2 anotações remapeadas
# Arquivo c_120.txt: 2 anotações remapeadas
# Arquivo c_121.txt: 2 anotações remapeadas
# Arquivo c_122.txt: 2 anotações remapeadas
# Arquivo c_123.txt: 2 anotações remapeadas
# Arquivo c_124.txt: 2 anotações remapeadas
# Arquivo c_125.txt: 2 anotações remapeadas
# Arquivo c_126.txt: 2 anotações remapeadas
# Arquivo c_127.txt: 2 anotações remapeadas
# Arquivo c_128.txt: 2 anotações remapeadas
# Arquivo c_129.txt: 2 anotações remapeadas
# Arquivo c_130.txt: 2 anotações remapeadas
# Arquivo c_131.txt: 2 anotações remapeadas
# Arquivo c_132.txt: 2 anotações remapeadas
# Arquivo c_133.txt: 2 anotações remapeadas
# Arquivo c_134.txt: 2 anotações remapeadas
# Arquivo c_135.txt: 2 anotações remapeadas
# Arquivo c_136.txt: 2 anotações remapeadas
# Arquivo c_137.txt: 2 anotações remapeadas
# Arquivo c_138.txt: 2 anotações remapeadas
# Arquivo c_139.txt: 2 anotações remapeadas
# Arquivo c_140.txt: 2 anotações remapeadas
# Arquivo c_141.txt: 2 anotações remapeadas
# Arquivo c_142.txt: 2 anotações remapeadas
# Arquivo c_143.txt: 2 anotações remapeadas
# Arquivo c_144.txt: 2 anotações remapeadas
# Arquivo c_145.txt: 2 anotações remapeadas
# Arquivo c_146.txt: 2 anotações remapeadas
# Arquivo c_147.txt: 2 anotações remapeadas
# Arquivo c_148.txt: 2 anotações remapeadas
# Arquivo c_149.txt: 2 anotações remapeadas
# Arquivo c_69.txt: 2 anotações remapeadas
# Arquivo c_70.txt: 2 anotações remapeadas
# Arquivo c_71.txt: 2 anotações remapeadas
# Arquivo c_72.txt: 2 anotações remapeadas
# Arquivo c_73.txt: 2 anotações remapeadas
# Arquivo c_74.txt: 2 anotações remapeadas
# Arquivo c_75.txt: 2 anotações remapeadas
# Arquivo c_76.txt: 2 anotações remapeadas
# Arquivo c_77.txt: 2 anotações remapeadas
# Arquivo c_78.txt: 2 anotações remapeadas
# Arquivo c_79.txt: 2 anotações remapeadas
# Arquivo c_80.txt: 2 anotações remapeadas
# Arquivo c_81.txt: 2 anotações remapeadas
# Arquivo c_82.txt: 2 anotações remapeadas
# Arquivo c_83.txt: 2 anotações remapeadas
# Arquivo c_84.txt: 2 anotações remapeadas
# Arquivo c_85.txt: 2 anotações remapeadas
# Arquivo c_86.txt: 2 anotações remapeadas
# Arquivo c_87.txt: 2 anotações remapeadas
# Arquivo c_88.txt: 2 anotações remapeadas
# Arquivo c_89.txt: 2 anotações remapeadas
# Arquivo c_90.txt: 2 anotações remapeadas
# Arquivo c_91.txt: 2 anotações remapeadas
# Arquivo c_92.txt: 2 anotações remapeadas
# Arquivo c_93.txt: 2 anotações remapeadas
# Arquivo c_94.txt: 2 anotações remapeadas
# Arquivo c_95.txt: 2 anotações remapeadas
# Arquivo c_96.txt: 2 anotações remapeadas
# Arquivo c_97.txt: 2 anotações remapeadas
# Arquivo c_98.txt: 2 anotações remapeadas
# Arquivo c_99.txt: 2 anotações remapeadas
# Arquivo dv_0.txt: 6 anotações remapeadas
# Arquivo dv_1199.txt: 5 anotações remapeadas
# Arquivo dv_1409.txt: 5 anotações remapeadas
# Arquivo d_267.txt: 6 anotações remapeadas
# Arquivo d_268.txt: 6 anotações remapeadas
# Arquivo d_269.txt: 6 anotações remapeadas
# Arquivo d_270.txt: 6 anotações remapeadas
# Arquivo d_271.txt: 6 anotações remapeadas
# Arquivo d_272.txt: 6 anotações remapeadas
# Arquivo d_273.txt: 6 anotações remapeadas
# Arquivo d_274.txt: 6 anotações remapeadas
# Arquivo d_275.txt: 6 anotações remapeadas
# Arquivo d_276.txt: 6 anotações remapeadas
# Arquivo d_277.txt: 6 anotações remapeadas
# Arquivo d_278.txt: 6 anotações remapeadas
# Arquivo d_279.txt: 6 anotações remapeadas
# Arquivo d_280.txt: 6 anotações remapeadas
# Arquivo d_281.txt: 6 anotações remapeadas
# Arquivo d_282.txt: 6 anotações remapeadas
# Arquivo d_283.txt: 6 anotações remapeadas
# Arquivo d_284.txt: 6 anotações remapeadas
# Arquivo d_285.txt: 6 anotações remapeadas
# Arquivo d_286.txt: 6 anotações remapeadas
# Arquivo d_287.txt: 6 anotações remapeadas
# Arquivo d_288.txt: 6 anotações remapeadas
# Arquivo d_289.txt: 6 anotações remapeadas
# Arquivo d_290.txt: 6 anotações remapeadas
# Arquivo d_291.txt: 6 anotações remapeadas
# Arquivo d_292.txt: 6 anotações remapeadas
# Arquivo d_293.txt: 6 anotações remapeadas
# Arquivo d_294.txt: 6 anotações remapeadas
# Arquivo d_295.txt: 6 anotações remapeadas
# Arquivo d_296.txt: 6 anotações remapeadas
# Arquivo d_297.txt: 6 anotações remapeadas
# Arquivo d_298.txt: 6 anotações remapeadas
# Arquivo d_299.txt: 6 anotações remapeadas
# Arquivo d_300.txt: 6 anotações remapeadas
# Arquivo d_301.txt: 6 anotações remapeadas
# Arquivo d_302.txt: 6 anotações remapeadas
# Arquivo d_303.txt: 6 anotações remapeadas
# Arquivo d_304.txt: 6 anotações remapeadas
# Arquivo d_305.txt: 6 anotações remapeadas
# Arquivo d_306.txt: 6 anotações remapeadas
# Arquivo d_307.txt: 6 anotações remapeadas
# Arquivo d_308.txt: 6 anotações remapeadas
# Arquivo d_309.txt: 6 anotações remapeadas
# Arquivo d_310.txt: 6 anotações remapeadas
# Arquivo d_311.txt: 6 anotações remapeadas
# Arquivo d_312.txt: 6 anotações remapeadas
# Arquivo d_313.txt: 6 anotações remapeadas
# Arquivo d_314.txt: 5 anotações remapeadas
# Arquivo d_315.txt: 5 anotações remapeadas
# Arquivo d_316.txt: 5 anotações remapeadas
# Arquivo d_317.txt: 4 anotações remapeadas
# Arquivo d_318.txt: 4 anotações remapeadas
# Arquivo d_319.txt: 4 anotações remapeadas
# Arquivo d_320.txt: 4 anotações remapeadas
# Arquivo d_321.txt: 4 anotações remapeadas
# Arquivo d_322.txt: 4 anotações remapeadas
# Arquivo d_323.txt: 4 anotações remapeadas
# Arquivo d_324.txt: 4 anotações remapeadas
# Arquivo d_325.txt: 4 anotações remapeadas
# Arquivo d_326.txt: 4 anotações remapeadas
# Arquivo d_327.txt: 4 anotações remapeadas
# Arquivo d_328.txt: 4 anotações remapeadas
# Arquivo d_329.txt: 4 anotações remapeadas
# Arquivo d_330.txt: 4 anotações remapeadas
# Arquivo d_331.txt: 4 anotações remapeadas
# Arquivo d_332.txt: 4 anotações remapeadas
# Arquivo d_333.txt: 4 anotações remapeadas
# Arquivo d_334.txt: 4 anotações remapeadas
# Arquivo d_335.txt: 4 anotações remapeadas
# Arquivo d_336.txt: 4 anotações remapeadas
# Arquivo d_337.txt: 4 anotações remapeadas
# Arquivo d_338.txt: 4 anotações remapeadas
# Arquivo d_339.txt: 4 anotações remapeadas
# Arquivo d_340.txt: 4 anotações remapeadas
# Arquivo d_341.txt: 4 anotações remapeadas
# Arquivo d_342.txt: 4 anotações remapeadas
# Arquivo d_343.txt: 4 anotações remapeadas
# Arquivo d_344.txt: 4 anotações remapeadas
# Arquivo d_345.txt: 5 anotações remapeadas
# Arquivo d_346.txt: 5 anotações remapeadas
# Arquivo d_347.txt: 5 anotações remapeadas
# Arquivo d_348.txt: 6 anotações remapeadas
# Arquivo d_349.txt: 6 anotações remapeadas
# Arquivo d_350.txt: 6 anotações remapeadas
# Arquivo d_351.txt: 6 anotações remapeadas
# Arquivo d_352.txt: 6 anotações remapeadas
# Arquivo d_353.txt: 6 anotações remapeadas
# Arquivo d_354.txt: 6 anotações remapeadas
# Arquivo d_355.txt: 6 anotações remapeadas
# Arquivo d_356.txt: 6 anotações remapeadas
# Arquivo d_357.txt: 6 anotações remapeadas
# Arquivo d_358.txt: 6 anotações remapeadas
# Arquivo d_359.txt: 6 anotações remapeadas
# Arquivo d_360.txt: 6 anotações remapeadas
# Arquivo d_361.txt: 6 anotações remapeadas
# Arquivo d_362.txt: 6 anotações remapeadas
# Arquivo d_363.txt: 6 anotações remapeadas
# Arquivo d_364.txt: 6 anotações remapeadas
# Arquivo d_365.txt: 6 anotações remapeadas
# Arquivo d_366.txt: 6 anotações remapeadas
# Arquivo d_367.txt: 5 anotações remapeadas
# Arquivo d_416.txt: 6 anotações remapeadas
# Arquivo d_417.txt: 6 anotações remapeadas
# Arquivo d_418.txt: 6 anotações remapeadas
# Arquivo d_419.txt: 6 anotações remapeadas
# Arquivo d_420.txt: 6 anotações remapeadas
# Arquivo d_421.txt: 6 anotações remapeadas
# Arquivo d_422.txt: 6 anotações remapeadas
# Arquivo d_423.txt: 6 anotações remapeadas
# Arquivo d_424.txt: 6 anotações remapeadas
# Arquivo d_425.txt: 6 anotações remapeadas
# Arquivo d_426.txt: 6 anotações remapeadas
# Arquivo d_427.txt: 6 anotações remapeadas
# Arquivo d_428.txt: 6 anotações remapeadas
# Arquivo d_429.txt: 6 anotações remapeadas
# Arquivo d_430.txt: 6 anotações remapeadas
# Arquivo d_431.txt: 6 anotações remapeadas
# Arquivo d_432.txt: 6 anotações remapeadas
# Arquivo d_433.txt: 6 anotações remapeadas
# Arquivo d_434.txt: 6 anotações remapeadas
# Arquivo d_435.txt: 6 anotações remapeadas
# Arquivo d_436.txt: 6 anotações remapeadas
# Arquivo d_437.txt: 5 anotações remapeadas
# Arquivo d_438.txt: 5 anotações remapeadas
# Arquivo d_439.txt: 5 anotações remapeadas
# Arquivo d_440.txt: 5 anotações remapeadas
# Arquivo d_441.txt: 5 anotações remapeadas
# Arquivo d_442.txt: 5 anotações remapeadas
# Arquivo d_443.txt: 5 anotações remapeadas
# Arquivo d_444.txt: 5 anotações remapeadas
# Arquivo d_445.txt: 5 anotações remapeadas
# Arquivo d_446.txt: 5 anotações remapeadas
# Arquivo d_447.txt: 5 anotações remapeadas
# Arquivo d_448.txt: 5 anotações remapeadas
# Arquivo d_449.txt: 5 anotações remapeadas
# Arquivo d_450.txt: 5 anotações remapeadas
# Arquivo d_451.txt: 5 anotações remapeadas
# Arquivo d_452.txt: 5 anotações remapeadas
# Arquivo d_453.txt: 5 anotações remapeadas
# Arquivo d_454.txt: 5 anotações remapeadas
# Arquivo d_455.txt: 5 anotações remapeadas
# Arquivo i2_155.txt: 2 anotações remapeadas
# Arquivo i2_156.txt: 2 anotações remapeadas
# Arquivo i2_157.txt: 2 anotações remapeadas
# Arquivo i2_158.txt: 2 anotações remapeadas
# Arquivo i2_159.txt: 2 anotações remapeadas
# Arquivo i2_160.txt: 2 anotações remapeadas
# Arquivo i2_161.txt: 2 anotações remapeadas
# Arquivo i2_162.txt: 1 anotações remapeadas
# Arquivo i2_163.txt: 1 anotações remapeadas
# Arquivo i2_164.txt: 1 anotações remapeadas
# Arquivo i3_132.txt: 1 anotações remapeadas
# Arquivo i3_133.txt: 1 anotações remapeadas
# Arquivo i3_134.txt: 1 anotações remapeadas
# Arquivo i3_135.txt: 1 anotações remapeadas
# Arquivo i3_136.txt: 1 anotações remapeadas
# Arquivo i3_137.txt: 1 anotações remapeadas
# Arquivo i3_138.txt: 1 anotações remapeadas
# Arquivo i3_139.txt: 1 anotações remapeadas
# Arquivo i3_140.txt: 1 anotações remapeadas
# Arquivo i3_141.txt: 1 anotações remapeadas
# Arquivo i3_142.txt: 1 anotações remapeadas
# Arquivo i3_143.txt: 1 anotações remapeadas
# Arquivo i3_144.txt: 1 anotações remapeadas
# Arquivo i3_145.txt: 1 anotações remapeadas
# Arquivo i3_146.txt: 1 anotações remapeadas
# Arquivo i3_147.txt: 1 anotações remapeadas
# Arquivo i3_148.txt: 1 anotações remapeadas
# Arquivo i3_149.txt: 1 anotações remapeadas
# Arquivo i3_150.txt: 1 anotações remapeadas
# Arquivo i3_151.txt: 1 anotações remapeadas
# Arquivo i3_152.txt: 1 anotações remapeadas
# Arquivo i3_153.txt: 1 anotações remapeadas
# Arquivo i3_154.txt: 1 anotações remapeadas
# Arquivo j1_151.txt: 1 anotações remapeadas
# Arquivo j1_152.txt: 1 anotações remapeadas
# Arquivo j1_153.txt: 1 anotações remapeadas
# Arquivo j1_154.txt: 1 anotações remapeadas
# Arquivo j1_155.txt: 1 anotações remapeadas
# Arquivo j1_156.txt: 1 anotações remapeadas
# Arquivo j1_157.txt: 1 anotações remapeadas
# Arquivo j1_158.txt: 1 anotações remapeadas
# Arquivo j1_159.txt: 1 anotações remapeadas
# Arquivo j1_160.txt: 1 anotações remapeadas
# Arquivo j1_161.txt: 1 anotações remapeadas
# Arquivo j1_162.txt: 1 anotações remapeadas
# Arquivo j1_163.txt: 1 anotações remapeadas
# Arquivo j2_237.txt: 1 anotações remapeadas
# Arquivo j2_238.txt: 1 anotações remapeadas
# Arquivo j2_239.txt: 1 anotações remapeadas
# Arquivo j2_240.txt: 1 anotações remapeadas
# Arquivo j2_241.txt: 1 anotações remapeadas
# Arquivo j2_242.txt: 1 anotações remapeadas
# Arquivo j2_243.txt: 1 anotações remapeadas
# Arquivo j2_244.txt: 1 anotações remapeadas
# Arquivo j2_245.txt: 1 anotações remapeadas
# Arquivo j2_246.txt: 1 anotações remapeadas
# Arquivo j2_247.txt: 1 anotações remapeadas
# Arquivo j2_248.txt: 1 anotações remapeadas
# Arquivo j2_37.txt: 1 anotações remapeadas
# Arquivo j2_38.txt: 1 anotações remapeadas
# Arquivo j2_39.txt: 1 anotações remapeadas
# Arquivo j2_40.txt: 1 anotações remapeadas
# Arquivo j2_41.txt: 1 anotações remapeadas
# Arquivo j2_42.txt: 1 anotações remapeadas
# Arquivo j2_43.txt: 1 anotações remapeadas
# Arquivo r2_0.txt: 3 anotações remapeadas
# Arquivo r2_1.txt: 3 anotações remapeadas
# Arquivo r2_13.txt: 3 anotações remapeadas
# Arquivo r2_14.txt: 3 anotações remapeadas
# Arquivo r2_15.txt: 3 anotações remapeadas
# Arquivo r2_16.txt: 3 anotações remapeadas
# Arquivo r2_17.txt: 3 anotações remapeadas
# Arquivo r2_18.txt: 3 anotações remapeadas
# Arquivo r2_19.txt: 3 anotações remapeadas
# Arquivo r2_2.txt: 3 anotações remapeadas
# Arquivo r2_20.txt: 3 anotações remapeadas
# Arquivo r2_21.txt: 3 anotações remapeadas
# Arquivo r2_22.txt: 3 anotações remapeadas
# Arquivo r2_23.txt: 3 anotações remapeadas
# Arquivo r2_24.txt: 3 anotações remapeadas
# Arquivo r2_25.txt: 3 anotações remapeadas
# Arquivo r2_26.txt: 3 anotações remapeadas
# Arquivo r2_27.txt: 3 anotações remapeadas
# Arquivo r2_28.txt: 3 anotações remapeadas
# Arquivo r2_29.txt: 3 anotações remapeadas
# Arquivo r2_30.txt: 3 anotações remapeadas
# Arquivo r2_31.txt: 3 anotações remapeadas
# Arquivo r2_32.txt: 3 anotações remapeadas
# Arquivo r2_33.txt: 3 anotações remapeadas
# Arquivo r2_34.txt: 3 anotações remapeadas
# Arquivo r2_35.txt: 3 anotações remapeadas
# Arquivo r2_36.txt: 3 anotações remapeadas
# Arquivo r2_37.txt: 3 anotações remapeadas
# Arquivo r2_38.txt: 3 anotações remapeadas
# Arquivo r2_39.txt: 3 anotações remapeadas
# Arquivo r2_40.txt: 3 anotações remapeadas
# Arquivo r2_41.txt: 3 anotações remapeadas
# Arquivo r2_42.txt: 3 anotações remapeadas
# Arquivo r2_43.txt: 3 anotações remapeadas
# Arquivo r2_44.txt: 3 anotações remapeadas
# Arquivo r2_46.txt: 3 anotações remapeadas
# Arquivo r2_47.txt: 3 anotações remapeadas
# Arquivo r2_48.txt: 3 anotações remapeadas
# Arquivo r2_49.txt: 3 anotações remapeadas
# Arquivo r2_5.txt: 3 anotações remapeadas
# Arquivo r2_50.txt: 3 anotações remapeadas
# Arquivo r2_51.txt: 3 anotações remapeadas
# Arquivo r2_52.txt: 3 anotações remapeadas
# Arquivo r2_53.txt: 3 anotações remapeadas
# Arquivo r2_54.txt: 3 anotações remapeadas
# Arquivo r2_55.txt: 3 anotações remapeadas
# Arquivo r2_56.txt: 3 anotações remapeadas
# Arquivo r2_57.txt: 3 anotações remapeadas
# Arquivo r2_58.txt: 3 anotações remapeadas
# Arquivo r2_59.txt: 3 anotações remapeadas
# Arquivo r2_60.txt: 3 anotações remapeadas
# Arquivo r2_61.txt: 3 anotações remapeadas
# Arquivo r2_62.txt: 3 anotações remapeadas
# Arquivo r2_63.txt: 3 anotações remapeadas
# Arquivo r2_64.txt: 3 anotações remapeadas
# Arquivo r2_65.txt: 2 anotações remapeadas
# Arquivo r2_66.txt: 2 anotações remapeadas
# Arquivo r2_67.txt: 2 anotações remapeadas
# Arquivo r2_68.txt: 2 anotações remapeadas
# Arquivo r2_69.txt: 2 anotações remapeadas
# Arquivo r2_7.txt: 3 anotações remapeadas
# Arquivo r2_74.txt: 3 anotações remapeadas
# Arquivo r2_75.txt: 3 anotações remapeadas
# Arquivo r2_76.txt: 3 anotações remapeadas
# Arquivo r2_77.txt: 3 anotações remapeadas
# Arquivo r2_78.txt: 3 anotações remapeadas
# Arquivo r2_79.txt: 3 anotações remapeadas
# Arquivo r2_8.txt: 3 anotações remapeadas
# Arquivo r2_80.txt: 3 anotações remapeadas
# Arquivo r2_81.txt: 3 anotações remapeadas
# Arquivo r2_82.txt: 3 anotações remapeadas
# Arquivo r2_83.txt: 3 anotações remapeadas
# Arquivo r2_84.txt: 3 anotações remapeadas
# Arquivo r2_85.txt: 3 anotações remapeadas
# Arquivo r2_86.txt: 3 anotações remapeadas
# Arquivo r2_87.txt: 3 anotações remapeadas
# Arquivo r2_88.txt: 3 anotações remapeadas
# Arquivo r2_89.txt: 3 anotações remapeadas
# Arquivo r2_9.txt: 3 anotações remapeadas
# Arquivo r2_90.txt: 3 anotações remapeadas
# Arquivo r2_91.txt: 3 anotações remapeadas
# Arquivo r2_92.txt: 3 anotações remapeadas
# Arquivo r2_93.txt: 3 anotações remapeadas
# Arquivo r2_94.txt: 3 anotações remapeadas
# Arquivo r2_95.txt: 3 anotações remapeadas
# Arquivo r3_100.txt: 1 anotações remapeadas
# Arquivo r3_101.txt: 1 anotações remapeadas
# Arquivo r3_102.txt: 1 anotações remapeadas
# Arquivo r3_103.txt: 1 anotações remapeadas
# Arquivo r3_104.txt: 1 anotações remapeadas
# Arquivo r3_105.txt: 1 anotações remapeadas
# Arquivo r3_107.txt: 1 anotações remapeadas
# Arquivo r3_108.txt: 1 anotações remapeadas
# Arquivo r3_109.txt: 1 anotações remapeadas
# Arquivo r3_110.txt: 1 anotações remapeadas
# Arquivo r3_111.txt: 1 anotações remapeadas
# Arquivo r3_112.txt: 1 anotações remapeadas
# Arquivo r3_113.txt: 1 anotações remapeadas
# Arquivo r3_114.txt: 1 anotações remapeadas
# Arquivo r3_115.txt: 1 anotações remapeadas
# Arquivo r3_116.txt: 1 anotações remapeadas
# Arquivo r3_117.txt: 1 anotações remapeadas
# Arquivo r3_118.txt: 1 anotações remapeadas
# Arquivo r3_119.txt: 1 anotações remapeadas
# Arquivo r3_120.txt: 1 anotações remapeadas
# Arquivo r3_121.txt: 1 anotações remapeadas
# Arquivo r3_122.txt: 1 anotações remapeadas
# Arquivo r3_123.txt: 1 anotações remapeadas
# Arquivo r3_124.txt: 1 anotações remapeadas
# Arquivo r3_125.txt: 1 anotações remapeadas
# Arquivo r3_126.txt: 1 anotações remapeadas
# Arquivo r3_153.txt: 3 anotações remapeadas
# Arquivo r3_154.txt: 3 anotações remapeadas
# Arquivo r3_155.txt: 3 anotações remapeadas
# Arquivo r3_156.txt: 3 anotações remapeadas
# Arquivo r3_157.txt: 3 anotações remapeadas
# Arquivo r3_158.txt: 3 anotações remapeadas
# Arquivo r3_159.txt: 3 anotações remapeadas
# Arquivo r3_160.txt: 3 anotações remapeadas
# Arquivo r3_161.txt: 3 anotações remapeadas
# Arquivo r3_162.txt: 3 anotações remapeadas
# Arquivo r3_163.txt: 3 anotações remapeadas
# Arquivo r3_164.txt: 3 anotações remapeadas
# Arquivo r3_165.txt: 3 anotações remapeadas
# Arquivo r3_166.txt: 3 anotações remapeadas
# Arquivo r3_167.txt: 3 anotações remapeadas
# Arquivo r3_168.txt: 3 anotações remapeadas
# Arquivo r3_169.txt: 3 anotações remapeadas
# Arquivo r3_170.txt: 2 anotações remapeadas
# Arquivo r3_171.txt: 2 anotações remapeadas
# Arquivo r3_172.txt: 2 anotações remapeadas
# Arquivo r3_173.txt: 2 anotações remapeadas
# Arquivo r3_174.txt: 2 anotações remapeadas
# Arquivo r3_175.txt: 2 anotações remapeadas
# Arquivo r3_176.txt: 2 anotações remapeadas
# Arquivo r3_177.txt: 2 anotações remapeadas
# Arquivo r3_178.txt: 2 anotações remapeadas
# Arquivo r3_179.txt: 2 anotações remapeadas
# Arquivo r3_180.txt: 2 anotações remapeadas
# Arquivo r3_181.txt: 2 anotações remapeadas
# Arquivo r3_182.txt: 3 anotações remapeadas
# Arquivo r3_183.txt: 3 anotações remapeadas
# Arquivo r3_184.txt: 3 anotações remapeadas
# Arquivo r3_185.txt: 3 anotações remapeadas
# Arquivo r3_186.txt: 3 anotações remapeadas
# Arquivo r3_187.txt: 3 anotações remapeadas
# Arquivo r3_188.txt: 3 anotações remapeadas
# Arquivo r3_189.txt: 3 anotações remapeadas
# Arquivo r3_190.txt: 3 anotações remapeadas
# Arquivo r3_191.txt: 3 anotações remapeadas
# Arquivo r3_192.txt: 3 anotações remapeadas
# Arquivo r3_193.txt: 3 anotações remapeadas
# Arquivo r3_194.txt: 3 anotações remapeadas
# Arquivo r3_195.txt: 3 anotações remapeadas
# Arquivo r3_196.txt: 3 anotações remapeadas
# Arquivo r3_197.txt: 3 anotações remapeadas
# Arquivo r3_198.txt: 3 anotações remapeadas
# Arquivo r3_199.txt: 3 anotações remapeadas
# Arquivo r3_200.txt: 3 anotações remapeadas
# Arquivo r3_201.txt: 3 anotações remapeadas
# Arquivo r3_202.txt: 3 anotações remapeadas
# Arquivo r3_203.txt: 3 anotações remapeadas
# ...
# Arquivo r3_462.txt: 3 anotações remapeadas
# Arquivo r3_463.txt: 3 anotações remapeadas
# Arquivo r3_464.txt: 3 anotações remapeadas
# Arquivo r3_47.txt: 2 anotações remapeadas
# Arquivo r3_48.txt: 2 anotações remapeadas
# Arquivo r3_49.txt: 2 anotações remapeadas
# Arquivo r3_55.txt: 2 anotações remapeadas
# Arquivo r3_56.txt: 2 anotações remapeadas
# Arquivo r3_57.txt: 2 anotações remapeadas
# Arquivo r3_58.txt: 2 anotações remapeadas
# Arquivo r3_59.txt: 2 anotações remapeadas
# Arquivo r3_60.txt: 2 anotações remapeadas
# Arquivo r3_61.txt: 2 anotações remapeadas
# Arquivo r3_62.txt: 2 anotações remapeadas
# Arquivo r3_63.txt: 2 anotações remapeadas
# Arquivo r3_64.txt: 2 anotações remapeadas
# Arquivo r3_65.txt: 2 anotações remapeadas
# Arquivo r3_66.txt: 2 anotações remapeadas
# Arquivo r3_67.txt: 2 anotações remapeadas
# Arquivo r3_68.txt: 2 anotações remapeadas
# Arquivo r3_69.txt: 2 anotações remapeadas
# Arquivo r3_70.txt: 2 anotações remapeadas
# Arquivo r3_71.txt: 2 anotações remapeadas
# Arquivo r3_72.txt: 2 anotações remapeadas
# Arquivo r3_73.txt: 2 anotações remapeadas
# Arquivo r3_74.txt: 2 anotações remapeadas
# Arquivo r3_75.txt: 2 anotações remapeadas
# Arquivo r3_76.txt: 2 anotações remapeadas
# Arquivo r3_77.txt: 2 anotações remapeadas
# Arquivo r3_78.txt: 2 anotações remapeadas
# Arquivo r3_79.txt: 2 anotações remapeadas
# Arquivo r3_80.txt: 2 anotações remapeadas
# Arquivo r3_81.txt: 2 anotações remapeadas
# Arquivo r3_82.txt: 2 anotações remapeadas
# Arquivo r3_83.txt: 2 anotações remapeadas
# Arquivo r3_84.txt: 2 anotações remapeadas
# Arquivo r3_85.txt: 2 anotações remapeadas
# Arquivo r3_86.txt: 2 anotações remapeadas
# Arquivo r3_87.txt: 2 anotações remapeadas
# Arquivo r3_88.txt: 2 anotações remapeadas
# Arquivo r3_89.txt: 2 anotações remapeadas
# Arquivo r3_92.txt: 1 anotações remapeadas
# Arquivo r3_93.txt: 1 anotações remapeadas
# Arquivo r3_94.txt: 1 anotações remapeadas
# Arquivo r3_95.txt: 1 anotações remapeadas
# Arquivo r3_96.txt: 1 anotações remapeadas
# Arquivo r3_97.txt: 1 anotações remapeadas
# Arquivo r3_98.txt: 1 anotações remapeadas
# Arquivo r3_99.txt: 1 anotações remapeadas
# Arquivo r4_0.txt: 3 anotações remapeadas
# Arquivo r4_1.txt: 3 anotações remapeadas
# Arquivo r4_10.txt: 3 anotações remapeadas
# Arquivo r4_100.txt: 3 anotações remapeadas
# Arquivo r4_101.txt: 3 anotações remapeadas
# Arquivo r4_102.txt: 3 anotações remapeadas
# Arquivo r4_103.txt: 3 anotações remapeadas
# Arquivo r4_104.txt: 3 anotações remapeadas
# Arquivo r4_105.txt: 3 anotações remapeadas
# Arquivo r4_106.txt: 3 anotações remapeadas
# Arquivo r4_107.txt: 3 anotações remapeadas
# Arquivo r4_108.txt: 3 anotações remapeadas
# Arquivo r4_109.txt: 3 anotações remapeadas
# Arquivo r4_11.txt: 3 anotações remapeadas
# Arquivo r4_110.txt: 3 anotações remapeadas
# Arquivo r4_111.txt: 3 anotações remapeadas
# Arquivo r4_112.txt: 2 anotações remapeadas
# Arquivo r4_113.txt: 2 anotações remapeadas
# Arquivo r4_114.txt: 2 anotações remapeadas
# Arquivo r4_115.txt: 2 anotações remapeadas
# Arquivo r4_116.txt: 2 anotações remapeadas
# Arquivo r4_117.txt: 2 anotações remapeadas
# Arquivo r4_118.txt: 2 anotações remapeadas
# Arquivo r4_119.txt: 2 anotações remapeadas
# Arquivo r4_12.txt: 3 anotações remapeadas
# Arquivo r4_120.txt: 2 anotações remapeadas
# Arquivo r4_121.txt: 2 anotações remapeadas
# Arquivo r4_122.txt: 2 anotações remapeadas
# Arquivo r4_13.txt: 3 anotações remapeadas
# Arquivo r4_14.txt: 3 anotações remapeadas
# Arquivo r4_15.txt: 3 anotações remapeadas
# Arquivo r4_16.txt: 3 anotações remapeadas
# Arquivo r4_17.txt: 3 anotações remapeadas
# Arquivo r4_18.txt: 3 anotações remapeadas
# Arquivo r4_19.txt: 3 anotações remapeadas
# Arquivo r4_2.txt: 3 anotações remapeadas
# Arquivo r4_20.txt: 3 anotações remapeadas
# Arquivo r4_21.txt: 3 anotações remapeadas
# Arquivo r4_22.txt: 3 anotações remapeadas
# Arquivo r4_23.txt: 3 anotações remapeadas
# Arquivo r4_24.txt: 3 anotações remapeadas
# Arquivo r4_25.txt: 3 anotações remapeadas
# Arquivo r4_26.txt: 3 anotações remapeadas
# Arquivo r4_27.txt: 3 anotações remapeadas
# Arquivo r4_28.txt: 3 anotações remapeadas
# Arquivo r4_29.txt: 3 anotações remapeadas
# Arquivo r4_3.txt: 3 anotações remapeadas
# Arquivo r4_30.txt: 3 anotações remapeadas
# Arquivo r4_31.txt: 3 anotações remapeadas
# Arquivo r4_32.txt: 3 anotações remapeadas
# Arquivo r4_33.txt: 3 anotações remapeadas
# Arquivo r4_34.txt: 3 anotações remapeadas
# Arquivo r4_35.txt: 3 anotações remapeadas
# Arquivo r4_36.txt: 3 anotações remapeadas
# Arquivo r4_37.txt: 3 anotações remapeadas
# Arquivo r4_38.txt: 3 anotações remapeadas
# Arquivo r4_39.txt: 3 anotações remapeadas
# Arquivo r4_4.txt: 3 anotações remapeadas
# Arquivo r4_40.txt: 3 anotações remapeadas
# Arquivo r4_41.txt: 3 anotações remapeadas
# Arquivo r4_42.txt: 3 anotações remapeadas
# Arquivo r4_43.txt: 3 anotações remapeadas
# Arquivo r4_44.txt: 3 anotações remapeadas
# Arquivo r4_45.txt: 3 anotações remapeadas
# Arquivo r4_46.txt: 3 anotações remapeadas
# Arquivo r4_47.txt: 3 anotações remapeadas
# Arquivo r4_48.txt: 3 anotações remapeadas
# Arquivo r4_49.txt: 3 anotações remapeadas
# Arquivo r4_5.txt: 3 anotações remapeadas
# Arquivo r4_50.txt: 3 anotações remapeadas
# Arquivo r4_51.txt: 3 anotações remapeadas
# Arquivo r4_52.txt: 3 anotações remapeadas
# Arquivo r4_53.txt: 3 anotações remapeadas
# Arquivo r4_54.txt: 3 anotações remapeadas
# Arquivo r4_55.txt: 3 anotações remapeadas
# Arquivo r4_56.txt: 3 anotações remapeadas
# Arquivo r4_57.txt: 3 anotações remapeadas
# Arquivo r4_58.txt: 3 anotações remapeadas
# Arquivo r4_59.txt: 3 anotações remapeadas
# Arquivo r4_6.txt: 3 anotações remapeadas
# Arquivo r4_60.txt: 2 anotações remapeadas
# Arquivo r4_61.txt: 2 anotações remapeadas
# Arquivo r4_62.txt: 2 anotações remapeadas
# Arquivo r4_63.txt: 1 anotações remapeadas
# Arquivo r4_64.txt: 1 anotações remapeadas
# Arquivo r4_65.txt: 1 anotações remapeadas
# Arquivo r4_66.txt: 1 anotações remapeadas
# Arquivo r4_67.txt: 1 anotações remapeadas
# Arquivo r4_68.txt: 1 anotações remapeadas
# Arquivo r4_69.txt: 1 anotações remapeadas
# Arquivo r4_7.txt: 3 anotações remapeadas
# Arquivo r4_70.txt: 2 anotações remapeadas
# Arquivo r4_71.txt: 2 anotações remapeadas
# Arquivo r4_72.txt: 2 anotações remapeadas
# Arquivo r4_73.txt: 2 anotações remapeadas
# Arquivo r4_74.txt: 2 anotações remapeadas
# Arquivo r4_75.txt: 2 anotações remapeadas
# Arquivo r4_76.txt: 2 anotações remapeadas
# Arquivo r4_77.txt: 2 anotações remapeadas
# Arquivo r4_78.txt: 3 anotações remapeadas
# Arquivo r4_79.txt: 3 anotações remapeadas
# Arquivo r4_8.txt: 3 anotações remapeadas
# Arquivo r4_80.txt: 3 anotações remapeadas
# Arquivo r4_81.txt: 3 anotações remapeadas
# Arquivo r4_82.txt: 3 anotações remapeadas
# Arquivo r4_83.txt: 3 anotações remapeadas
# Arquivo r4_84.txt: 3 anotações remapeadas
# Arquivo r4_85.txt: 3 anotações remapeadas
# Arquivo r4_86.txt: 3 anotações remapeadas
# Arquivo r4_87.txt: 3 anotações remapeadas
# Arquivo r4_88.txt: 3 anotações remapeadas
# Arquivo r4_89.txt: 3 anotações remapeadas
# Arquivo r4_9.txt: 3 anotações remapeadas
# Arquivo r4_90.txt: 3 anotações remapeadas
# Arquivo r4_91.txt: 3 anotações remapeadas
# Arquivo r4_92.txt: 3 anotações remapeadas
# Arquivo r4_93.txt: 3 anotações remapeadas
# Arquivo r4_94.txt: 3 anotações remapeadas
# Arquivo r4_95.txt: 3 anotações remapeadas
# Arquivo r4_96.txt: 3 anotações remapeadas
# Arquivo r4_97.txt: 3 anotações remapeadas
# Arquivo r4_98.txt: 3 anotações remapeadas
# Arquivo r4_99.txt: 3 anotações remapeadas
# Arquivo s1_11.txt: 1 anotações remapeadas
# Arquivo s1_138.txt: 1 anotações remapeadas
# Arquivo s1_257.txt: 1 anotações remapeadas
# Arquivo s1_8.txt: 1 anotações remapeadas
# Arquivo s1_82.txt: 1 anotações remapeadas
# Arquivo s1_9.txt: 1 anotações remapeadas
# Arquivo s5_165.txt: 1 anotações remapeadas
# Arquivo w1_10.txt: 6 anotações remapeadas
# Arquivo w1_100.txt: 1 anotações remapeadas
# Arquivo w1_101.txt: 1 anotações remapeadas
# Arquivo w1_102.txt: 1 anotações remapeadas
# Arquivo w1_106.txt: 4 anotações remapeadas
# Arquivo w1_108.txt: 3 anotações remapeadas
# Arquivo w1_111.txt: 5 anotações remapeadas
# Arquivo w1_114.txt: 4 anotações remapeadas
# Arquivo w1_116.txt: 3 anotações remapeadas
# Arquivo w1_128.txt: 1 anotações remapeadas
# Arquivo w1_129.txt: 1 anotações remapeadas
# Arquivo w1_13.txt: 8 anotações remapeadas
# Arquivo w1_133.txt: 1 anotações remapeadas
# Arquivo w1_138.txt: 1 anotações remapeadas
# Arquivo w1_144.txt: 1 anotações remapeadas
# Arquivo w1_148.txt: 1 anotações remapeadas
# Arquivo w1_15.txt: 8 anotações remapeadas
# Arquivo w1_154.txt: 2 anotações remapeadas
# Arquivo w1_157.txt: 2 anotações remapeadas
# Arquivo w1_16.txt: 7 anotações remapeadas
# Arquivo w1_17.txt: 6 anotações remapeadas
# Arquivo w1_171.txt: 3 anotações remapeadas
# Arquivo w1_175.txt: 4 anotações remapeadas
# Arquivo w1_179.txt: 4 anotações remapeadas
# Arquivo w1_18.txt: 5 anotações remapeadas
# Arquivo w1_189.txt: 4 anotações remapeadas
# Arquivo w1_193.txt: 3 anotações remapeadas
# Arquivo w1_198.txt: 1 anotações remapeadas
# Arquivo w1_259.txt: 2 anotações remapeadas
# Arquivo w1_261.txt: 3 anotações remapeadas
# Arquivo w1_267.txt: 3 anotações remapeadas
# Arquivo w1_271.txt: 3 anotações remapeadas
# Arquivo w1_275.txt: 9 anotações remapeadas
# Arquivo w1_280.txt: 7 anotações remapeadas
# Arquivo w1_287.txt: 7 anotações remapeadas
# Arquivo w1_290.txt: 9 anotações remapeadas
# Arquivo w1_296.txt: 6 anotações remapeadas
# Arquivo w1_299.txt: 5 anotações remapeadas
# Arquivo w1_303.txt: 8 anotações remapeadas
# Arquivo w1_310.txt: 5 anotações remapeadas
# Arquivo w1_319.txt: 3 anotações remapeadas
# Arquivo w1_330.txt: 5 anotações remapeadas
# Arquivo w1_343.txt: 6 anotações remapeadas
# Arquivo w1_352.txt: 5 anotações remapeadas
# Arquivo w1_361.txt: 1 anotações remapeadas
# Arquivo w1_362.txt: 1 anotações remapeadas
# Arquivo w1_365.txt: 1 anotações remapeadas
# Arquivo w1_367.txt: 1 anotações remapeadas
# Arquivo w1_369.txt: 1 anotações remapeadas
# Arquivo w1_374.txt: 3 anotações remapeadas
# Arquivo w1_376.txt: 3 anotações remapeadas
# Arquivo w1_380.txt: 5 anotações remapeadas
# Arquivo w1_387.txt: 4 anotações remapeadas
# Arquivo w1_394.txt: 7 anotações remapeadas
# Arquivo w1_399.txt: 11 anotações remapeadas
# Arquivo w1_403.txt: 12 anotações remapeadas
# Arquivo w1_409.txt: 12 anotações remapeadas
# Arquivo w1_418.txt: 3 anotações remapeadas
# Arquivo w1_419.txt: 3 anotações remapeadas
# Arquivo w1_422.txt: 1 anotações remapeadas
# Arquivo w1_423.txt: 1 anotações remapeadas
# Arquivo w1_431.txt: 1 anotações remapeadas
# Arquivo w1_433.txt: 1 anotações remapeadas
# Arquivo w1_434.txt: 1 anotações remapeadas
# Arquivo w1_436.txt: 1 anotações remapeadas
# Arquivo w1_438.txt: 1 anotações remapeadas
# Arquivo w1_439.txt: 1 anotações remapeadas
# Arquivo w1_441.txt: 1 anotações remapeadas
# Arquivo w1_443.txt: 2 anotações remapeadas
# Arquivo w1_445.txt: 2 anotações remapeadas
# Arquivo w1_447.txt: 5 anotações remapeadas
# Arquivo w1_450.txt: 6 anotações remapeadas
# Arquivo w1_451.txt: 6 anotações remapeadas
# Arquivo w1_459.txt: 7 anotações remapeadas
# Arquivo w1_463.txt: 7 anotações remapeadas
# Arquivo w1_466.txt: 9 anotações remapeadas
# Arquivo w1_469.txt: 3 anotações remapeadas
# Arquivo w1_473.txt: 4 anotações remapeadas
# Arquivo w1_474.txt: 3 anotações remapeadas
# Arquivo w1_475.txt: 3 anotações remapeadas
# Arquivo w1_479.txt: 3 anotações remapeadas
# Arquivo w1_491.txt: 3 anotações remapeadas
# Arquivo w1_492.txt: 3 anotações remapeadas
# Arquivo w2_0.txt: 3 anotações remapeadas
# Arquivo w2_100.txt: 3 anotações remapeadas
# Arquivo w2_104.txt: 1 anotações remapeadas
# Arquivo w2_106.txt: 1 anotações remapeadas
# Arquivo w2_109.txt: 1 anotações remapeadas
# Arquivo w2_112.txt: 3 anotações remapeadas
# Arquivo w2_114.txt: 3 anotações remapeadas
# Arquivo w2_12.txt: 2 anotações remapeadas
# Arquivo w2_16.txt: 3 anotações remapeadas
# Arquivo w2_171.txt: 2 anotações remapeadas
# Arquivo w2_175.txt: 2 anotações remapeadas
# Arquivo w2_179.txt: 3 anotações remapeadas
# Arquivo w2_189.txt: 3 anotações remapeadas
# Arquivo w2_19.txt: 1 anotações remapeadas
# Arquivo w2_191.txt: 3 anotações remapeadas
# Arquivo w2_20.txt: 1 anotações remapeadas
# Arquivo w2_202.txt: 1 anotações remapeadas
# Arquivo w2_205.txt: 1 anotações remapeadas
# Arquivo w2_22.txt: 1 anotações remapeadas
# Arquivo w2_221.txt: 1 anotações remapeadas
# Arquivo w2_223.txt: 1 anotações remapeadas
# Arquivo w2_231.txt: 1 anotações remapeadas
# Arquivo w2_234.txt: 1 anotações remapeadas
# Arquivo w2_240.txt: 2 anotações remapeadas
# Arquivo w2_25.txt: 1 anotações remapeadas
# Arquivo w2_28.txt: 1 anotações remapeadas
# Arquivo w2_31.txt: 1 anotações remapeadas
# Arquivo w2_38.txt: 2 anotações remapeadas
# Arquivo w2_40.txt: 2 anotações remapeadas
# Arquivo w2_43.txt: 2 anotações remapeadas
# Arquivo w2_54.txt: 2 anotações remapeadas
# Arquivo w2_58.txt: 1 anotações remapeadas
# Arquivo w2_63.txt: 2 anotações remapeadas
# Arquivo wv_165.txt: 2 anotações remapeadas
# Arquivo wv_341.txt: 6 anotações remapeadas
# Arquivo wv_356.txt: 5 anotações remapeadas
# Arquivo wv_411.txt: 8 anotações remapeadas
# Arquivo wv_42.txt: 1 anotações remapeadas
# Arquivo wv_456.txt: 3 anotações remapeadas
# Arquivo wv_92.txt: 1 anotações remapeadas
# Arquivo z2_0.txt: 1 anotações remapeadas
# Arquivo z2_1.txt: 1 anotações remapeadas
# Arquivo z2_10.txt: 1 anotações remapeadas
# Arquivo z2_11.txt: 1 anotações remapeadas
# Arquivo z2_12.txt: 1 anotações remapeadas
# Arquivo z2_13.txt: 1 anotações remapeadas
# Arquivo z2_14.txt: 1 anotações remapeadas
# Arquivo z2_15.txt: 1 anotações remapeadas
# Arquivo z2_16.txt: 1 anotações remapeadas
# Arquivo z2_17.txt: 1 anotações remapeadas
# Arquivo z2_18.txt: 1 anotações remapeadas
# Arquivo z2_19.txt: 1 anotações remapeadas
# Arquivo z2_2.txt: 1 anotações remapeadas
# Arquivo z2_20.txt: 1 anotações remapeadas
# Arquivo z2_21.txt: 1 anotações remapeadas
# Arquivo z2_22.txt: 1 anotações remapeadas
# Arquivo z2_23.txt: 1 anotações remapeadas
# Arquivo z2_24.txt: 1 anotações remapeadas
# Arquivo z2_25.txt: 1 anotações remapeadas
# Arquivo z2_26.txt: 1 anotações remapeadas
# Arquivo z2_27.txt: 1 anotações remapeadas
# Arquivo z2_28.txt: 1 anotações remapeadas
# Arquivo z2_29.txt: 1 anotações remapeadas
# Arquivo z2_3.txt: 1 anotações remapeadas
# Arquivo z2_30.txt: 1 anotações remapeadas
# Arquivo z2_31.txt: 1 anotações remapeadas
# Arquivo z2_32.txt: 1 anotações remapeadas
# Arquivo z2_33.txt: 1 anotações remapeadas
# Arquivo z2_34.txt: 1 anotações remapeadas
# Arquivo z2_35.txt: 1 anotações remapeadas
# Arquivo z2_36.txt: 1 anotações remapeadas
# Arquivo z2_37.txt: 1 anotações remapeadas
# Arquivo z2_38.txt: 1 anotações remapeadas
# Arquivo z2_39.txt: 1 anotações remapeadas
# Arquivo z2_4.txt: 1 anotações remapeadas
# Arquivo z2_40.txt: 1 anotações remapeadas
# Arquivo z2_41.txt: 1 anotações remapeadas
# Arquivo z2_5.txt: 1 anotações remapeadas
# Arquivo z2_6.txt: 1 anotações remapeadas
# Arquivo z2_7.txt: 1 anotações remapeadas
# Arquivo z2_8.txt: 1 anotações remapeadas
# Arquivo z2_9.txt: 1 anotações remapeadas
# Arquivo z3_399.txt: 3 anotações remapeadas
# Arquivo z3_45.txt: 3 anotações remapeadas
# Arquivo z3_46.txt: 3 anotações remapeadas
# Arquivo z3_47.txt: 3 anotações remapeadas
# Arquivo z3_48.txt: 3 anotações remapeadas
# Arquivo z3_49.txt: 3 anotações remapeadas
# Arquivo z3_50.txt: 2 anotações remapeadas
# Arquivo z3_51.txt: 2 anotações remapeadas
# Arquivo z3_52.txt: 2 anotações remapeadas
# Arquivo z3_53.txt: 2 anotações remapeadas
# Arquivo z3_54.txt: 2 anotações remapeadas
# Arquivo z3_55.txt: 1 anotações remapeadas
# Arquivo z3_56.txt: 1 anotações remapeadas
# Arquivo z3_57.txt: 1 anotações remapeadas
# Arquivo z3_58.txt: 1 anotações remapeadas
# Arquivo z3_59.txt: 1 anotações remapeadas
# Arquivo z3_60.txt: 1 anotações remapeadas
# Arquivo z3_61.txt: 1 anotações remapeadas
# Arquivo z3_62.txt: 1 anotações remapeadas
# Arquivo z3_63.txt: 1 anotações remapeadas
# Arquivo z3_64.txt: 1 anotações remapeadas
# Arquivo z3_65.txt: 1 anotações remapeadas
# Arquivo z3_66.txt: 1 anotações remapeadas
# Arquivo z3_67.txt: 1 anotações remapeadas
# Arquivo z3_68.txt: 1 anotações remapeadas
# Arquivo z3_69.txt: 1 anotações remapeadas
# Arquivo z3_70.txt: 1 anotações remapeadas
# Arquivo z3_71.txt: 1 anotações remapeadas
# Arquivo z3_72.txt: 2 anotações remapeadas
#
# Etapa 1 concluída!
#   - 2912 arquivos processados
#   - 5528 anotações remapeadas no total
#   - Arquivos salvos em: remapped_annotations
#   - Agora você tem apenas classes: human (0) e boat (2)

# %%
import os

# --- Configurações de Caminho ---
input_dir = "remapped_annotations"  # Pasta da etapa anterior
output_dir = "final_human_boat_dataset"  # Pasta final com human(0) e boat(1)

# Cria o diretório de saída se não existir
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Pasta de destino '{output_dir}' criada.")

# --- Mapeamento Final ---
# Da etapa anterior temos: human(0) e boat(2)
# Agora queremos: human(0) e boat(1)

final_mapping = {
    0: 0,  # human -> human (mantém 0)
    2: 1   # boat -> boat (muda para 1)
}

print("Mapeamento final:")
print("  human (0) -> human (0)")
print("  boat (2) -> boat (1)")

# --- Processar arquivos ---
processed_files = 0
total_annotations = 0
human_count = 0
boat_count = 0

for filename in os.listdir(input_dir):
    if filename.endswith(".txt"):
        input_filepath = os.path.join(input_dir, filename)
        output_filepath = os.path.join(output_dir, filename)
        
        final_annotations = []
        
        with open(input_filepath, 'r') as infile:
            for line in infile:
                parts = line.strip().split()
                if not parts:
                    continue
                
                try:
                    class_id = int(parts[0])
                    
                    # Aplicar mapeamento final
                    if class_id in final_mapping:
                        new_class_id = final_mapping[class_id]
                        parts[0] = str(new_class_id)
                        
                        # Contar as classes
                        if new_class_id == 0:
                            human_count += 1
                        elif new_class_id == 1:
                            boat_count += 1
                        
                        total_annotations += 1
                        final_annotations.append(' '.join(parts) + '\n')
                    else:
                        print(f"Aviso: Classe {class_id} inesperada em {filename}")
                        
                except ValueError:
                    print(f"Aviso: Linha inválida ignorada em {filename}: {line.strip()}")
                    continue
        
        # Escrever arquivo final
        if final_annotations:
            with open(output_filepath, 'w') as outfile:
                for annotation in final_annotations:
                    outfile.write(annotation)
        
        processed_files += 1

# Criar arquivo .names para o dataset final
names_file = os.path.join(output_dir, "classes.names")
with open(names_file, 'w') as f:
    f.write("human\n")
    f.write("boat\n")

print(f"\nEtapa 2 concluída!")
print(f"  - {processed_files} arquivos processados")
print(f"  - {total_annotations} anotações totais")
print(f"  - {human_count} anotações de human (classe 0)")
print(f"  - {boat_count} anotações de boat (classe 1)")
print(f"  - Arquivos salvos em: {output_dir}")
print(f"  - Arquivo de classes criado: {names_file}")
print(f"\nDataset final pronto com apenas 2 classes: human(0) e boat(1)!")
# Out:
# Pasta de destino 'final_human_boat_dataset' criada.
# Mapeamento final:
#   human (0) -> human (0)
#   boat (2) -> boat (1)
#
# Etapa 2 concluída!
#   - 2912 arquivos processados
#   - 39404 anotações totais
#   - 37096 anotações de human (classe 0)
#   - 2308 anotações de boat (classe 1)
#   - Arquivos salvos em: final_human_boat_dataset
#   - Arquivo de classes criado: final_human_boat_dataset\classes.names
#
# Dataset final pronto com apenas 2 classes: human(0) e boat(1)!

# %%
import os
import shutil
import random
from pathlib import Path

def organize_yolo_dataset(images_dir, annotations_dir, output_dir, train_ratio=0.7, val_ratio=0.2, test_ratio=0.1):
    """
    Organiza dataset YOLO em pastas train/val/test
    
    Args:
        images_dir: caminho para pasta com imagens .jpg
        annotations_dir: caminho para pasta com anotações .txt
        output_dir: caminho onde criar as pastas organizadas
        train_ratio: proporção para treino (0.7 = 70%)
        val_ratio: proporção para validação (0.2 = 20%)
        test_ratio: proporção para teste (0.1 = 10%)
    """
    
    # Criar estrutura de pastas
    output_path = Path(output_dir)
    for split in ['train', 'val', 'test']:
        (output_path / split / 'images').mkdir(parents=True, exist_ok=True)
        (output_path / split / 'labels').mkdir(parents=True, exist_ok=True)
    
    # Listar todas as imagens
    images_path = Path(images_dir)
    image_files = list(images_path.glob('*.jpg'))
    
    # Verificar se existem anotações correspondentes
    annotations_path = Path(annotations_dir)
    valid_pairs = []
    
    for img_file in image_files:
        txt_file = annotations_path / f"{img_file.stem}.txt"
        if txt_file.exists():
            valid_pairs.append((img_file, txt_file))
        else:
            print(f"Aviso: Anotação não encontrada para {img_file.name}")
    
    print(f"Total de pares válidos (imagem + anotação): {len(valid_pairs)}")
    
    # Embaralhar os dados
    random.shuffle(valid_pairs)
    
    # Calcular divisões
    total = len(valid_pairs)
    train_end = int(total * train_ratio)
    val_end = train_end + int(total * val_ratio)
    
    splits = {
        'train': valid_pairs[:train_end],
        'val': valid_pairs[train_end:val_end],
        'test': valid_pairs[val_end:]
    }
    
    # Copiar arquivos para as respectivas pastas
    for split_name, pairs in splits.items():
        print(f"\nCopiando {len(pairs)} arquivos para {split_name}...")
        
        for img_file, txt_file in pairs:
            # Copiar imagem
            dst_img = output_path / split_name / 'images' / img_file.name
            shutil.copy2(img_file, dst_img)
            
            # Copiar anotação
            dst_txt = output_path / split_name / 'labels' / txt_file.name
            shutil.copy2(txt_file, dst_txt)
    
    print(f"\nDataset organizado com sucesso!")
    print(f"Train: {len(splits['train'])} amostras")
    print(f"Val: {len(splits['val'])} amostras") 
    print(f"Test: {len(splits['test'])} amostras")

# %%
# Substitua pelos seus caminhos reais
organize_yolo_dataset(
    images_dir='final_human_boat_dataset',
    annotations_dir='remapped_annotations', 
    output_dir='dataset_yolo'
)
# Out:
# Total de pares válidos (imagem + anotação): 0
#
# Copiando 0 arquivos para train...
#
# Copiando 0 arquivos para val...
#
# Copiando 0 arquivos para test...
#
# Dataset organizado com sucesso!
# Train: 0 amostras
# Val: 0 amostras
# Test: 0 amostras
