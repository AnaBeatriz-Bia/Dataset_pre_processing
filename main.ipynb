# %%
import os
import shutil
from PIL import Image # Para verificar dimensões da imagem para os bboxes
import matplotlib.pyplot as plt # Para visualização de bboxes
import matplotlib.patches as patches # Para desenhar retângulos
import cv2 # Usado na seção de verificação opcional, pode ser necessário para ler imagens

# %%
import os
import shutil

# --- Configurações de Caminho ---
FINAL_MERGED_IMAGE_DIR = "all_dataset_images" # Nome da pasta para juntar todas as imagens

# Certifica-se de que a pasta de destino final existe
if not os.path.exists(FINAL_MERGED_IMAGE_DIR):
    os.makedirs(FINAL_MERGED_IMAGE_DIR)
    print(f"Pasta de destino '{FINAL_MERGED_IMAGE_DIR}' criada.")

# Diretórios de onde as imagens serão COLETADAS
image_dirs = [
    'PART_1/PART_1/images',
    'PART_2/PART_2/images',
    'PART_3/PART_3/images'
]

# Extensões de arquivo de imagem que serão consideradas
IMAGE_EXTENSIONS = ('.jpg', '.jpeg', '.png')

# --- Processo de Junção de Imagens ---

print("\nIniciando a cópia das imagens...")
copied_image_count = 0

for source_dir in image_dirs:
    # Verifica se o diretório de origem existe antes de tentar listar
    if not os.path.exists(source_dir):
        print(f"Aviso: Diretório de origem '{source_dir}' não encontrado. Pulando...")
        continue

    print(f"Processando diretório: {source_dir}")
    for fname in os.listdir(source_dir):
        # Verifica se o arquivo é uma imagem pela extensão
        if fname.lower().endswith(IMAGE_EXTENSIONS):
            source_image_path = os.path.join(source_dir, fname)
            base_name, extension = os.path.splitext(fname)
            destination_image_name = f"{base_name}{extension}"
            destination_image_path = os.path.join(FINAL_MERGED_IMAGE_DIR, destination_image_name)

            try:
                shutil.copy2(source_image_path, destination_image_path)
                # print(f"Copiado: {source_image_path} -> {destination_image_path}")
                copied_image_count += 1
            except Exception as e:
                print(f"ERRO ao copiar '{source_image_path}': {e}")

print(f"\nProcesso concluído. Total de {copied_image_count} imagens copiadas para '{FINAL_MERGED_IMAGE_DIR}'.")
# Out:
# Iniciando a cópia das imagens...
# Processando diretório: PART_1/PART_1/images
# Processando diretório: PART_2/PART_2/images
# Processando diretório: PART_3/PART_3/images
#
# Processo concluído. Total de 3641 imagens copiadas para 'all_dataset_images'.

# %%
import os
import shutil

# --- Configurações de Caminho ---
FINAL_MERGED_ANNOTATION = "all_dataset_annotations" # Nome da pasta para juntar todas as anotações

# Certifica-se de que a pasta de destino final existe
if not os.path.exists(FINAL_MERGED_ANNOTATION):
    os.makedirs(FINAL_MERGED_ANNOTATION)
    print(f"Pasta de destino '{FINAL_MERGED_ANNOTATION}' criada.")

# Diretórios de onde as anotações serão COLETADAS
ANNOTATIONs = ['PART_1/PART_1/6categories']

# Extensões de arquivo de imagem que serão consideradas
ANNOTATIONs_EXTENSION = ('.txt')

# --- Processo de Junção de anotações ---

print("\nIniciando a cópia das anotações...")
copied_image_count = 0

for source_dir in ANNOTATIONs:
    # Verifica se o diretório de origem existe antes de tentar listar
    if not os.path.exists(source_dir):
        print(f"Aviso: Diretório de origem '{source_dir}' não encontrado. Pulando...")
        continue

    print(f"Processando diretório: {source_dir}")
    for fname in os.listdir(source_dir):
        # Verifica se o arquivo é uma imagem pela extensão
        if fname.lower().endswith(ANNOTATIONs_EXTENSION):
            source_image_path = os.path.join(source_dir, fname)
            base_name, extension = os.path.splitext(fname)
            destination_image_name = f"{base_name}{extension}"
            destination_image_path = os.path.join(FINAL_MERGED_ANNOTATION, destination_image_name)

            try:
                shutil.copy2(source_image_path, destination_image_path)
                # print(f"Copiado: {source_image_path} -> {destination_image_path}")
                copied_image_count += 1
            except Exception as e:
                print(f"ERRO ao copiar '{source_image_path}': {e}")

print(f"\nProcesso concluído. Total de {copied_image_count} anotações copiadas para '{FINAL_MERGED_ANNOTATION}'.")
# Out:
# Iniciando a cópia das anotações...
# Processando diretório: PART_1/PART_1/6categories
#
# Processo concluído. Total de 3641 anotações copiadas para 'all_dataset_annotations'.

# %%
import os

# Define o caminho para a pasta de anotações e o arquivo de nomes das classes
annotations_dir = "all_dataset_annotations"
names_file = "PART_1/PART_1/6categories.names"
# Sugiro um novo nome para o diretório de saída para não sobrescrever o anterior
output_dir = "cleaned_dataset_annotations_no_bouy" 

# Cria o diretório de saída se não existir
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 1. Ler o arquivo de nomes das classes para mapear nomes para índices
class_names = []
with open(names_file, 'r') as f:
    class_names = [line.strip() for line in f.readlines()]

# 2. Identificar o índice da classe a ser REMOVIDA ("bouy")
bouy_idx = -1
try:
    bouy_idx = class_names.index("bouy")
except ValueError:
    print(f"Erro: A classe 'bouy' não foi encontrada em {names_file}.")
    print(f"Classes lidas: {class_names}")
    exit()

print(f"Índice da classe 'bouy' a ser removida: {bouy_idx}")
print(f"Todas as outras classes serão mantidas: {', '.join([name for i, name in enumerate(class_names) if i != bouy_idx])}")

# 3. Iterar sobre cada arquivo de anotação no diretório
for filename in os.listdir(annotations_dir):
    if filename.endswith(".txt"):
        input_filepath = os.path.join(annotations_dir, filename)
        output_filepath = os.path.join(output_dir, filename)
        
        kept_annotations = [] # Renomeado para maior clareza
        
        with open(input_filepath, 'r') as infile:
            for line in infile:
                parts = line.strip().split()
                if not parts:
                    continue
                
                try:
                    class_id = int(parts[0])
                    # Manter a linha APENAS SE a classe NÃO FOR 'bouy'
                    if class_id != bouy_idx:
                        kept_annotations.append(line)
                except ValueError:
                    print(f"Aviso: Linha inválida ignorada em {filename}: {line.strip()}")
                    continue
        
        # 4. Escrever as anotações filtradas em um novo arquivo
        if kept_annotations:
            with open(output_filepath, 'w') as outfile:
                for annotation in kept_annotations:
                    outfile.write(annotation)
            print(f"Arquivo filtrado salvo em: {output_filepath}")
        else:
            # Isso pode acontecer se um arquivo SÓ tinha anotações de 'bouy'
            print(f"Nenhuma anotação mantida para o arquivo: {filename} (após remover 'bouy'). Nenhum arquivo de saída gerado.")

print("\nLimpeza (remoção de 'bouy') concluída!")
# Out:
# Índice da classe 'bouy' a ser removida: 3
# Todas as outras classes serão mantidas: human, wind-sup-board, boat, sailboat, kayak
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\av_1381.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\av_249.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_101.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1013.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1014.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1015.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1016.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1017.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1018.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1019.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_102.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1020.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1021.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1022.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1023.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1024.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1025.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1026.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1027.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1028.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1029.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_103.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1030.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1031.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1032.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1033.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1034.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1035.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1036.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1037.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1038.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1039.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_104.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1040.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1041.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1042.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1043.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1044.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1045.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1046.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1047.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1048.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1049.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_105.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1050.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1051.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1052.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1053.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1054.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1055.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1056.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1057.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1058.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1059.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_106.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1060.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1061.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1062.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1063.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1064.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1065.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1066.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1067.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1068.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1069.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_107.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1070.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1071.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1072.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1073.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1074.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1075.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1076.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1077.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1078.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1079.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_108.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1080.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1081.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1082.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1083.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1084.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1085.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1086.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1087.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1088.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1089.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_109.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1090.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1091.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1092.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1093.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1094.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1095.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1096.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1097.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1098.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1099.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_110.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1100.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1101.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1102.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1103.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1104.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1105.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1106.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1107.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1108.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1109.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_111.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1110.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1111.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1112.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1113.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1114.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1115.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1116.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1117.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1118.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1119.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_112.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1120.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1121.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1122.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1123.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1124.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1125.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1126.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1127.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1128.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1129.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_113.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1130.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1131.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1132.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1133.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1134.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1135.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1136.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1137.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1138.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1139.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_114.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1140.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1141.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1142.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1143.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1144.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1145.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1146.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1147.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1148.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1149.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_115.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1150.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1151.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1152.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1153.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1154.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1155.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1156.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1157.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1158.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1159.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_116.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1160.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1161.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1162.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1163.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1164.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1165.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1166.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1167.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1168.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1169.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_117.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1170.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1171.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1172.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1173.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1174.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1175.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1176.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1177.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1178.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1179.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_118.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1180.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1181.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1182.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1183.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1184.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1185.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1186.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1187.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1188.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1189.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_119.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1190.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1191.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1192.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1193.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1194.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1195.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1196.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1197.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1198.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1199.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_120.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1200.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1201.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1202.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1203.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1204.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1205.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1206.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1207.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1208.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1209.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_121.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1210.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1211.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1212.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1213.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1214.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1215.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1216.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1217.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1218.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1219.txt
# Nenhuma anotação mantida para o arquivo: a_122.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1220.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1221.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1222.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1223.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1224.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1225.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1226.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1227.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1228.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1229.txt
# Nenhuma anotação mantida para o arquivo: a_123.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1230.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1231.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1232.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1233.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1234.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1235.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1236.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1237.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1238.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1239.txt
# Nenhuma anotação mantida para o arquivo: a_124.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1240.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1241.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1242.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1243.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1244.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1245.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1246.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1247.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1248.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1249.txt
# Nenhuma anotação mantida para o arquivo: a_125.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1250.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1251.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1252.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1253.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1254.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1255.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1256.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1257.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1258.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1259.txt
# Nenhuma anotação mantida para o arquivo: a_126.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1260.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1261.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1262.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1263.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_1264.txt
# Nenhuma anotação mantida para o arquivo: a_127.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_128.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_129.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_130.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_131.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_132.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_133.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_134.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_135.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_136.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_137.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_138.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_139.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_140.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_141.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_142.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_143.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_144.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_145.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_146.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_147.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_148.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_149.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_150.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_151.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_152.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_153.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_154.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_155.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_156.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_157.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_158.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_159.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Nenhuma anotação mantida para o arquivo: a_160.txt (após remover 'bouy'). Nenhum arquivo de saída gerado.
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_161.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_162.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_163.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_164.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_165.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_166.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_167.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_168.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_169.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_170.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_171.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_172.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_173.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_174.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_175.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_176.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_177.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_178.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_179.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_180.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_181.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_182.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_183.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_184.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_185.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_186.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_187.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_188.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_301.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_302.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_303.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_304.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_305.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_306.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_307.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_308.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_309.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_310.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_311.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_312.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_313.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_314.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_315.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_316.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_317.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_318.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_319.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_320.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_321.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_322.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_323.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_324.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_325.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_326.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_327.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_328.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_329.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_330.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_331.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_332.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_333.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_334.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_335.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_336.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_337.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_338.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_339.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_340.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_341.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_342.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_343.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_344.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_345.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_346.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_347.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_348.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_349.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_350.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_351.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_352.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_353.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_354.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_355.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_356.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_357.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_358.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_359.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_360.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_361.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_362.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_363.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_364.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_365.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_366.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_367.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_368.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_369.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_370.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_371.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_372.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_373.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_374.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_375.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_376.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_377.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_378.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_379.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_380.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_381.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_382.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_383.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_384.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_385.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_386.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_387.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_388.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_389.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_390.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_391.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_392.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_393.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_394.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_395.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_396.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_397.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_398.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_399.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_400.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_401.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_402.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_403.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_404.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_405.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_406.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_407.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_408.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_409.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_410.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_411.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_412.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_413.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_414.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_415.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_416.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_417.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_418.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_419.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_420.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_421.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_422.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_423.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_424.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_425.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_426.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_427.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_428.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_429.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_430.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_431.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_432.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_433.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_434.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_435.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_436.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_437.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_438.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_439.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_440.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_441.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_442.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_443.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_444.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_445.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_446.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_447.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_448.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_449.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\a_450.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_101.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_102.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_103.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_104.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_105.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_106.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_107.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_108.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_109.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_11.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_110.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_111.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_112.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_113.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_114.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_115.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_116.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_117.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_118.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_119.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_12.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_120.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_121.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_122.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_123.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_124.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_125.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_126.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_127.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_128.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_129.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_13.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_130.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_131.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_132.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_133.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_134.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_135.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_136.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_137.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_138.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_139.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_14.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_140.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_141.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_142.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_143.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_144.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_145.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_146.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_147.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_148.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_149.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_15.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_150.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_151.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_152.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_153.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_154.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_155.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_156.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_157.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_158.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_159.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_16.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_160.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_161.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_162.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_163.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_164.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_165.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_166.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_167.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_168.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_169.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_17.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_170.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_171.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_172.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_173.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_174.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_175.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_176.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_177.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_178.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_179.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_18.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_180.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_181.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_182.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_183.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_184.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_185.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_186.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_187.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_188.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_189.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_19.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_190.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_191.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_192.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_193.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_194.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_195.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_196.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_197.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_198.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_199.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_20.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_200.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_201.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_202.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_203.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_204.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_205.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_206.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_207.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_208.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_209.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_21.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_210.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_211.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_212.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_213.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_214.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_215.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_216.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_217.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_218.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_219.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_22.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_220.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_221.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_222.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_223.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_224.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_225.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_226.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_227.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\b1_228.txt
# ...
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_148.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_15.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_154.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_157.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_16.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_17.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_171.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_175.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_179.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_18.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_189.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_193.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_198.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_2.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_211.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_212.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_213.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_248.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_259.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_261.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_267.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_271.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_275.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_280.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_287.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_290.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_296.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_299.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_303.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_310.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_319.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_330.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_343.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_352.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_361.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_362.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_365.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_367.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_369.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_374.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_376.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_380.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_387.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_394.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_399.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_403.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_409.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_418.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_419.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_422.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_423.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_426.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_428.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_429.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_431.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_433.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_434.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_436.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_438.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_439.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_441.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_443.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_445.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_447.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_450.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_451.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_459.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_463.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_466.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_469.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_473.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_474.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_475.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_479.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_481.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_483.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_485.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_491.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w1_492.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_0.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_100.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_104.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_106.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_109.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_112.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_114.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_12.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_16.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_171.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_175.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_179.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_189.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_19.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_191.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_196.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_199.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_20.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_202.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_205.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_208.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_210.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_212.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_215.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_217.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_22.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_221.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_223.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_227.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_231.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_234.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_240.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_25.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_28.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_31.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_38.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_40.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_43.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_54.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_58.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\w2_63.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_165.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_341.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_356.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_411.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_42.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_456.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\wv_92.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_34.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_35.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_36.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_37.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_38.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_39.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_40.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_41.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_42.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_43.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_44.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_45.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_46.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_47.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_48.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_49.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_50.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_51.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z1_52.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_0.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_1.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_10.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_11.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_12.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_13.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_14.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_15.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_16.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_17.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_18.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_19.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_2.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_20.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_21.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_22.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_23.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_24.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_25.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_26.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_27.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_28.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_29.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_3.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_30.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_31.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_32.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_33.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_34.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_35.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_36.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_37.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_38.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_39.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_4.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_40.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_41.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_5.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_6.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_7.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_8.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z2_9.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_399.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_45.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_46.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_47.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_48.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_49.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_50.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_51.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_52.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_53.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_54.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_55.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_56.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_57.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_58.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_59.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_60.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_61.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_62.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_63.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_64.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_65.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_66.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_67.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_68.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_69.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_70.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_71.txt
# Arquivo filtrado salvo em: cleaned_dataset_annotations_no_bouy\z3_72.txt
#
# Limpeza (remoção de 'bouy') concluída!

# %%
import os

# --- Configurações ---
# Diretório com TODAS as imagens (com base no seu notebook, parece ser este)
images_dir = "all_dataset_images" 

# Diretório com as anotações JÁ LIMPAS (o resultado do seu script anterior)
annotations_dir = "cleaned_dataset_annotations_no_bouy"

# --- Lógica do Script ---

# 1. Obter a lista de nomes base das anotações existentes
# Usamos um 'set' para uma busca muito mais rápida
annotation_basenames = set()
for ann_file in os.listdir(annotations_dir):
    if ann_file.endswith(".txt"):
        # Pega o nome do arquivo sem a extensão .txt (ex: 'img_001')
        basename = os.path.splitext(ann_file)[0]
        annotation_basenames.add(basename)

print(f"Encontradas {len(annotation_basenames)} anotações limpas em '{annotations_dir}'.")

# 2. Identificar imagens que não têm uma anotação correspondente
images_to_delete = []
for img_file in os.listdir(images_dir):
    # Pega o nome do arquivo de imagem sem a extensão (ex: 'img_001')
    img_basename = os.path.splitext(img_file)[0]
    
    # Se o nome base da imagem NÃO está na lista de nomes de anotações, ela deve ser apagada
    if img_basename not in annotation_basenames:
        images_to_delete.append(os.path.join(images_dir, img_file))

# 3. Revisão e Confirmação (PASSO DE SEGURANÇA)
if not images_to_delete:
    print("\nNenhuma imagem para apagar. Todas as imagens têm anotações correspondentes.")
else:
    print(f"\nAs seguintes {len(images_to_delete)} imagens serão APAGADAS pois não possuem anotações:")
    print(images_to_delete)
    # Mostra as primeiras 10 imagens para o usuário ter uma ideia
    for i, image_path in enumerate(images_to_delete[:10]):
        print(f" - {os.path.basename(image_path)}")
    if len(images_to_delete) > 10:
        print(f"   ... e mais {len(images_to_delete) - 10} outras.")

    # Pede confirmação ao usuário antes de apagar qualquer coisa
    # Mude para 's' se seu sistema for em português
    user_input = input("\nVocê tem certeza que deseja apagar esses arquivos? (s/n): ").lower()
    
    # 4. Apagar os arquivos se confirmado
    if user_input == 's' or user_input == 'y':
        deleted_count = 0
        for image_path in images_to_delete:
            try:
                os.remove(image_path)
                deleted_count += 1
            except OSError as e:
                print(f"Erro ao apagar o arquivo {image_path}: {e}")
        
        print(f"\nProcesso concluído. {deleted_count} imagens foram apagadas.")
    else:
        print("\nOperação cancelada pelo usuário. Nenhum arquivo foi apagado.")
# Out:
# Encontradas 2912 anotações limpas em 'cleaned_dataset_annotations_no_bouy'.
#
# Nenhuma imagem para apagar. Todas as imagens têm anotações correspondentes.
